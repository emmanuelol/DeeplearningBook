# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# # Demo

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.165678
# Minibatch accuracy: 12.5%
# Validation accuracy: 9.2%
# Minibatch loss at step 50: 1.625847
# Minibatch accuracy: 37.5%
# Validation accuracy: 58.0%
# Minibatch loss at step 100: 1.100641
# Minibatch accuracy: 68.8%
# Validation accuracy: 69.5%
# Minibatch loss at step 150: 0.512150
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.7%
# Minibatch loss at step 200: 0.885062
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.8%
# Minibatch loss at step 250: 1.263190
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.367314
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 350: 0.563431
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.0%
# Minibatch loss at step 400: 0.214787
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 450: 0.938993
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 0.758343
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.838877
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.6%
# Minibatch loss at step 600: 0.299416
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 650: 0.996901
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 700: 0.888287
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 750: 0.072836
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 800: 0.576218
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.917609
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 900: 0.885563
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 950: 0.530048
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 0.463623
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Test accuracy: 89.0%

# %% [markdown]
# # Problema 1
# agregar max pooling con stride 2 y un kernel de 2

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  #kernel 5x5  
  #num_channels=1
  #depth=16  
  # 5x5x1x16  
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  # k 5x5
  # depth=16
  # depth=16
  #5x5x16x16  
    
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  #final image size
  final_image_size=7

  layer3_weights = tf.Variable(tf.truncated_normal(
      [final_image_size * final_image_size* depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    #pooling
    pool_1=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='SAME')
    
    
    conv = tf.nn.conv2d(pool_1, layer2_weights, strides=[1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    #pooling
    pool_2=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='SAME')
    
    shape = pool_2.get_shape().as_list()
    reshape = tf.reshape(pool_2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.224002
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.036684
# Minibatch accuracy: 12.5%
# Validation accuracy: 45.4%
# Minibatch loss at step 100: 1.414553
# Minibatch accuracy: 50.0%
# Validation accuracy: 58.9%
# Minibatch loss at step 150: 0.523655
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.6%
# Minibatch loss at step 200: 1.240701
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.4%
# Minibatch loss at step 250: 1.121413
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.7%
# Minibatch loss at step 300: 0.412098
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.6%
# Minibatch loss at step 350: 0.425354
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.1%
# Minibatch loss at step 400: 0.215412
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.884377
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.8%
# Minibatch loss at step 500: 0.430815
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 550: 0.805834
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 600: 0.372894
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 650: 1.034405
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 700: 0.793435
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 750: 0.047419
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 800: 0.516568
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 850: 0.765643
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 900: 0.642476
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 950: 0.589933
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 1000: 0.417068
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Test accuracy: 91.0%

# %% [markdown]
# # Problem 2
# implementacion de lenet5
# son 5 capas, 3 convnet y 2 fully conected usando avg pooling

# %%
batch_size = 16
patch_size = 5
depth = 6 # numero de filtros
depth2= 10
beta=0.001
num_hidden = 120
num_hidden_2=1920
num_hidden_3=84


graph = tf.Graph()

with graph.as_default():



  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  #kernel 5x5  
  #num_channels=1
  #depth=6  
  # 5x5x1x6 
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  # k 5x5
  # depth=6
  # depth=6
  #5x5x6x6  
    
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))

  # image size
  image_size_conv3=1

  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size_conv3 , image_size_conv3, depth2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
   # fully connected

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden_2, num_hidden_3], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden_3]))

  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden_3, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  #keep_prob=tf.placeholder("float")
  

  
  # Model.
  def model(data):
        #conv 1
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    #pooling
    pool_1=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='VALID')
    
    # Dropout
    #pool_1_drop=tf.nn.dropout(pool_1,keep_prob)
    
    #conv 2
    conv = tf.nn.conv2d(pool_1, layer2_weights, strides=[1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    #pooling
    pool_2=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='VALID')
    # Dropout
    #pool_2_drop=tf.nn.dropout(pool_2,keep_prob)
    
    #conv 3
    conv = tf.nn.conv2d(pool_2, layer3_weights, strides=[1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer3_biases)
    
    #pooling

    
    # Fully connected
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    #hidden = tf.nn.relu(tf.matmul(hidden, layer5_weights) + layer5_biases)
        
    
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  # regulizer
  #regularizers=tf.nn.l2_loss(layer1_weights)+tf.nn.l2_loss(layer2_weights)+tf.nn.l2_loss(layer3_weights)+tf.nn.l2_loss(layer4_weights)+tf.nn.l2_loss(layer5_weights)
  #loss=tf.reduce_mean(loss+beta*regularizers)
  loss=tf.reduce_mean(loss)
  # Optimizer.
  # agregando un learning rate descendiente
  #global_step=tf.Variable(0)
  #start_learning_rate=0.5
  #learning_rate=tf.train.exponential_decay(start_learning_rate,global_step,100000,0.96,staircase=True)
  learning_rate=1e-3  
  #optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)
  optimizer=tf.train.AdamOptimizer(learning_rate).minimize(loss) 
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.651897
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.274590
# Minibatch accuracy: 0.0%
# Validation accuracy: 11.6%
# Minibatch loss at step 100: 2.147465
# Minibatch accuracy: 18.8%
# Validation accuracy: 14.0%
# Minibatch loss at step 150: 1.373312
# Minibatch accuracy: 56.2%
# Validation accuracy: 33.4%
# Minibatch loss at step 200: 1.511415
# Minibatch accuracy: 50.0%
# Validation accuracy: 49.7%
# Minibatch loss at step 250: 1.604398
# Minibatch accuracy: 62.5%
# Validation accuracy: 61.8%
# Minibatch loss at step 300: 0.754268
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.5%
# Minibatch loss at step 350: 0.684232
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.3%
# Minibatch loss at step 400: 0.601235
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.1%
# Minibatch loss at step 450: 1.212390
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.9%
# Minibatch loss at step 500: 1.033692
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.7%
# Minibatch loss at step 550: 1.017380
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.0%
# Minibatch loss at step 600: 0.539243
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 650: 0.814692
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.2%
# Minibatch loss at step 700: 1.068024
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 750: 0.092638
# Minibatch accuracy: 100.0%
# Validation accuracy: 79.0%
# Minibatch loss at step 800: 0.525059
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.3%
# Minibatch loss at step 850: 0.905370
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 900: 0.750474
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
# Minibatch loss at step 950: 0.688120
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 1000: 0.455083
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 1050: 0.418225
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 1100: 0.550514
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 1150: 0.552381
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 1200: 1.108493
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 1250: 0.839003
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.4%
# Minibatch loss at step 1300: 0.330162
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 1350: 1.237492
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.4%
# Minibatch loss at step 1400: 0.310591
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 1450: 0.259819
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 1500: 0.951484
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.9%
# Minibatch loss at step 1550: 0.465409
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 1600: 1.168139
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1650: 0.840170
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 1700: 0.851382
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 1750: 0.506356
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1800: 0.568264
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 1850: 1.024797
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 1900: 0.388935
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 1950: 0.639880
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 2000: 0.209768
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 2050: 0.552770
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 2100: 0.114820
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 2150: 0.710683
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 2200: 0.642334
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 2250: 0.492324
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 2300: 0.683325
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 2350: 0.393741
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 2400: 0.462657
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 2450: 0.539627
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 2500: 0.601684
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 2550: 0.639859
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Minibatch loss at step 2600: 0.116283
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 2650: 0.398597
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2700: 0.635853
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 2750: 1.144016
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 2800: 0.506612
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 2850: 0.225467
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 2900: 0.531423
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 2950: 0.438514
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3000: 0.589284
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 3050: 0.584990
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 3100: 0.508450
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 3150: 0.682761
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 3200: 0.538520
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3250: 0.409760
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 3300: 0.120552
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 3350: 0.373513
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 3400: 0.545647
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.3%
# Minibatch loss at step 3450: 0.440404
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 3500: 0.393528
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 3550: 0.174231
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 3600: 0.052883
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 3650: 1.078525
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 3700: 1.022374
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 3750: 0.835628
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 3800: 0.006510
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 3850: 0.839526
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 3900: 0.335222
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.5%
# Minibatch loss at step 3950: 0.014170
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.0%
# Minibatch loss at step 4000: 0.355560
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 4050: 0.907875
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 4100: 0.457750
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 4150: 1.167490
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 4200: 0.229798
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 4250: 0.681963
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 4300: 0.740225
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 4350: 0.361974
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 4400: 1.035482
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 4450: 0.434251
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4500: 0.605793
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 4550: 0.370905
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 4600: 0.361804
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 4650: 0.877591
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.6%
# Minibatch loss at step 4700: 0.393221
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 4750: 1.028649
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 4800: 0.597819
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.2%
# Minibatch loss at step 4850: 0.346069
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 4900: 0.169821
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 4950: 0.329984
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 5000: 1.119239
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Test accuracy: 92.7%

# %% [markdown]
# # arquitectura del libro Tom

# %%
batch_size = 16
patch_size = 5
depth = 32 # numero de filtros
depth2= 64
beta=0.001
num_hidden = 1024



graph = tf.Graph()

with graph.as_default():



  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  #kernel 5x5  
  #num_channels=1
  #depth=32  
  # 5x5x1x32 
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  # k 5x5
  # depth=32
  # depth=64
  #5x5x32x64  
    
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))

  # image size

   # fully connected
  layer3_weights = tf.Variable(tf.truncated_normal(
      [7*7*depth2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))



  keep_prob=tf.placeholder("float")
  

  
  # Model.
  def model(data):
        #conv 1
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    #pooling
    pool_1=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='VALID')
    
    # Dropout
    #pool_1_drop=tf.nn.dropout(pool_1,keep_prob)
    
    #conv 2
    conv = tf.nn.conv2d(pool_1, layer2_weights, strides=[1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    #pooling
    pool_2=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='VALID')
    # Dropout
    #pool_2_drop=tf.nn.dropout(pool_2,keep_prob)
    

    
    #pooling

    
    # Fully connected
    
    shape = pool_2.get_shape().as_list()
    reshape = tf.reshape(pool_2, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    #hidden = tf.nn.relu(tf.matmul(hidden, layer5_weights) + layer5_biases)
    #hidden_dropout=  tf.nn.dropout(hidden,keep_prob)  
    
    return tf.nn.relu(tf.matmul(hidden,layer4_weights)+layer4_biases)
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  # regulizer
  #regularizers=tf.nn.l2_loss(layer1_weights)+tf.nn.l2_loss(layer2_weights)+tf.nn.l2_loss(layer3_weights)+tf.nn.l2_loss(layer4_weights)+tf.nn.l2_loss(layer5_weights)
  #loss=tf.reduce_mean(loss+beta*regularizers)
  loss=tf.reduce_mean(loss)
  # Optimizer.
  # agregando un learning rate descendiente
  #global_step=tf.Variable(0)
  #start_learning_rate=0.5
  #learning_rate=tf.train.exponential_decay(start_learning_rate,global_step,100000,0.96,staircase=True)
  learning_rate=1e-4  
  #optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)
  optimizer=tf.train.AdamOptimizer(learning_rate).minimize(loss) 
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 17.445410
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.4%
# Minibatch loss at step 50: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 11.9%
# Minibatch loss at step 100: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 12.2%
# Minibatch loss at step 150: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 200: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 250: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 300: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 350: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 400: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 450: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 500: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 550: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 600: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 650: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 700: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 750: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 800: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 850: 2.302585
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 900: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 950: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1000: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1050: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1100: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1150: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1200: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1250: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1300: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1350: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1400: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1450: 2.302585
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1500: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1550: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 1600: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1650: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1700: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 1750: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 1800: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 1850: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 1900: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 1950: 2.302585
# Minibatch accuracy: 31.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2000: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 2050: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 2100: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2150: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2200: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2250: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 2300: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 2350: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2400: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 2450: 2.302585
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2500: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2550: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2600: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2650: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2700: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 2750: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 2800: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 2850: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 2900: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 2950: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 3000: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3050: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3100: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3150: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 3200: 2.302585
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 3250: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3300: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3350: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 3400: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3450: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 3500: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 3550: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 3600: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 3650: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 3700: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 3750: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 3800: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 3850: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 3900: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 3950: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4000: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4050: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 4100: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4150: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4200: 2.302585
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 4250: 2.302585
# Minibatch accuracy: 31.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4300: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4350: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4400: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4450: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4500: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 4550: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4600: 2.302585
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 4650: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4700: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4750: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4800: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 4850: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4900: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 4950: 2.302585
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 5000: 2.302585
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Test accuracy: 10.0%
