# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# # Demo

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.616407
# Minibatch accuracy: 18.8%
# Validation accuracy: 6.3%
# Minibatch loss at step 50: 2.124728
# Minibatch accuracy: 6.2%
# Validation accuracy: 24.5%
# Minibatch loss at step 100: 1.133860
# Minibatch accuracy: 50.0%
# Validation accuracy: 65.5%
# Minibatch loss at step 150: 0.649188
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.5%
# Minibatch loss at step 200: 0.875023
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.6%
# Minibatch loss at step 250: 1.231954
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 300: 0.396033
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 350: 0.673941
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 400: 0.440414
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 450: 0.807265
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.2%
# Minibatch loss at step 500: 0.740571
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 550: 0.969617
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.9%
# Minibatch loss at step 600: 0.287115
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 650: 0.987004
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 700: 0.924271
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.6%
# Minibatch loss at step 750: 0.071674
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 800: 0.612556
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 850: 0.919282
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 900: 0.527123
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.630218
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 1000: 0.449382
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Test accuracy: 89.4%

# %% [markdown]
# # Problema 1
# agregar max pooling con stride 2 y un kernel de 2

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  #kernel 5x5  
  #num_channels=1
  #depth=16  
  # 5x5x1x16  
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  # k 5x5
  # depth=16
  # depth=16
  #5x5x16x16  
    
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))

  #final image size
  final_image_size=7

  layer3_weights = tf.Variable(tf.truncated_normal(
      [final_image_size * final_image_size* depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    #pooling
    pool_1=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='SAME')
    
    
    conv = tf.nn.conv2d(pool_1, layer2_weights, strides=[1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    #pooling
    pool_2=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='SAME')
    
    shape = pool_2.get_shape().as_list()
    reshape = tf.reshape(pool_2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.372034
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.8%
# Minibatch loss at step 50: 1.717983
# Minibatch accuracy: 37.5%
# Validation accuracy: 53.9%
# Minibatch loss at step 100: 0.838572
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.0%
# Minibatch loss at step 150: 0.411816
# Minibatch accuracy: 87.5%
# Validation accuracy: 75.1%
# Minibatch loss at step 200: 0.991601
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.7%
# Minibatch loss at step 250: 0.991772
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.0%
# Minibatch loss at step 300: 0.365989
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.3%
# Minibatch loss at step 350: 0.469051
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 400: 0.258659
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 450: 0.833306
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 500: 0.656598
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 550: 0.896239
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 600: 0.360029
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 650: 0.830290
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 700: 0.960923
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.4%
# Minibatch loss at step 750: 0.029956
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.705303
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 850: 0.898124
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 900: 0.649722
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 950: 0.559118
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 1000: 0.250605
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.3%
# Test accuracy: 90.5%

# %% [markdown]
# # Problem 2
# implementacion de lenet5
# son 5 capas, 3 convnet y 2 fully conected usando avg pooling

# %%
batch_size = 16
patch_size = 5
depth = 6 # numero de filtros
depth2= 10
beta=0.001
num_hidden = 120
num_hidden_2=1920
num_hidden_3=84


graph = tf.Graph()

with graph.as_default():



  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  #kernel 5x5  
  #num_channels=1
  #depth=6  
  # 5x5x1x6 
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  # k 5x5
  # depth=6
  # depth=6
  #5x5x6x6  
    
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))

  # image size
  image_size_conv3=1

  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size_conv3 , image_size_conv3, depth2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
    
   # fully connected

  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden_2, num_hidden_3], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden_3]))

  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden_3, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  #keep_prob=tf.placeholder("float")
  

  
  # Model.
  def model(data):
        #conv 1
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer1_biases)
    
    #pooling
    pool_1=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='VALID')
    
    # Dropout
    #pool_1_drop=tf.nn.dropout(pool_1,keep_prob)
    
    #conv 2
    conv = tf.nn.conv2d(pool_1, layer2_weights, strides=[1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer2_biases)
    
    #pooling
    pool_2=tf.nn.max_pool(hidden,[1,2,2,1],[1,2,2,1],padding='VALID')
    # Dropout
    #pool_2_drop=tf.nn.dropout(pool_2,keep_prob)
    
    #conv 3
    conv = tf.nn.conv2d(pool_2, layer3_weights, strides=[1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer3_biases)
    
    #pooling

    
    # Fully connected
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    #hidden = tf.nn.relu(tf.matmul(hidden, layer5_weights) + layer5_biases)
        
    
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
  # regulizer
  regularizers=tf.nn.l2_loss(layer1_weights)+tf.nn.l2_loss(layer2_weights)+tf.nn.l2_loss(layer3_weights)+tf.nn.l2_loss(layer4_weights)+tf.nn.l2_loss(layer5_weights)
  loss=tf.reduce_mean(loss+beta*regularizers)  
  # Optimizer.
  # agregando un learning rate descendiente
  #global_step=tf.Variable(0)
  #start_learning_rate=0.5
  #learning_rate=tf.train.exponential_decay(start_learning_rate,global_step,100000,0.96,staircase=True)
  learning_rate=1e-3  
  #optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss,global_step=global_step)
  optimizer=tf.train.AdamOptimizer(learning_rate).minimize(loss) 
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.817945
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.786181
# Minibatch accuracy: 12.5%
# Validation accuracy: 12.8%
# Minibatch loss at step 100: 2.470218
# Minibatch accuracy: 18.8%
# Validation accuracy: 21.0%
# Minibatch loss at step 150: 1.885601
# Minibatch accuracy: 56.2%
# Validation accuracy: 44.5%
# Minibatch loss at step 200: 1.752551
# Minibatch accuracy: 56.2%
# Validation accuracy: 63.3%
# Minibatch loss at step 250: 2.021340
# Minibatch accuracy: 62.5%
# Validation accuracy: 66.8%
# Minibatch loss at step 300: 1.116565
# Minibatch accuracy: 87.5%
# Validation accuracy: 74.2%
# Minibatch loss at step 350: 1.019544
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.4%
# Minibatch loss at step 400: 1.046383
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.3%
# Minibatch loss at step 450: 1.484921
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.5%
# Minibatch loss at step 500: 1.325922
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.0%
# Minibatch loss at step 550: 1.318117
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 600: 0.861413
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.9%
# Minibatch loss at step 650: 1.096524
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.0%
# Minibatch loss at step 700: 1.469823
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 750: 0.396108
# Minibatch accuracy: 100.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 800: 0.929134
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 850: 1.448763
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 900: 1.294122
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 950: 0.987504
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.1%
# Minibatch loss at step 1000: 0.766016
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 1050: 1.027375
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 1100: 0.986012
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 1150: 0.778182
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 1200: 1.571588
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 1250: 0.898509
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 1300: 0.566458
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 1350: 1.358750
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 1400: 0.590675
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 1450: 0.586558
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 1500: 0.852396
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 1550: 0.859900
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 1600: 1.519301
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 1650: 0.970990
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 1700: 0.962673
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 1750: 0.666183
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 1800: 0.613932
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 1850: 0.953497
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 1900: 0.552851
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 1950: 0.876463
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 2000: 0.306280
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 2050: 0.905281
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 2100: 0.293601
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 2150: 0.802781
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 2200: 0.613209
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 2250: 0.632137
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 2300: 0.912318
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 2350: 0.570476
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 2400: 0.596025
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 2450: 0.567106
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 2500: 1.113686
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 2550: 0.761399
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 2600: 0.477240
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 2650: 0.649141
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 2700: 0.727295
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 2750: 1.172239
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 2800: 0.696488
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 2850: 0.210356
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 2900: 0.675860
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 2950: 0.589804
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 3000: 0.727407
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3050: 0.679331
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.1%
# Minibatch loss at step 3100: 0.654179
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 3150: 0.725523
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3200: 0.720129
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3250: 0.501772
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 3300: 0.393383
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 3350: 0.421031
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 3400: 0.911475
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 3450: 0.480277
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 3500: 0.509363
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 3550: 0.336168
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 3600: 0.374891
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.0%
# Minibatch loss at step 3650: 1.083077
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 3700: 1.132204
# Minibatch accuracy: 62.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 3750: 0.948018
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.1%
# Minibatch loss at step 3800: 0.147885
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3850: 0.821397
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 3900: 0.569403
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3950: 0.144469
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 4000: 0.438255
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 4050: 0.904870
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 4100: 0.645641
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 4150: 1.142704
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 4200: 0.469368
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 4250: 0.751891
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 4300: 0.575954
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 4350: 0.335385
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 4400: 1.215708
# Minibatch accuracy: 62.5%
# Validation accuracy: 85.4%
# Minibatch loss at step 4450: 0.618439
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 4500: 0.709909
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 4550: 0.514579
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 4600: 0.699830
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4650: 1.032812
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 4700: 0.594736
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 4750: 1.232150
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4800: 0.582979
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 4850: 0.405748
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 4900: 0.176285
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 4950: 0.382342
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 5000: 0.936422
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.3%
# Test accuracy: 92.5%
