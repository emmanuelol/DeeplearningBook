# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'term', 'anarchism', 'originated', 'term', 'of', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.137710
# Nearest to d: modena, catalyzed, poetess, harbors, crashing, distillers, inspire, entitles,
# Nearest to from: palatinate, mno, maneuver, unorthodox, renting, werner, eps, warps,
# Nearest to s: threat, fida, maguire, christof, piccadilly, espn, rejuvenated, vikernes,
# Nearest to he: operations, tienne, cidre, demetrius, whistleblower, lupus, cke, ravel,
# Nearest to more: roleplaying, adair, billion, largest, encircles, spins, peabody, internetworking,
# Nearest to war: woefully, dedication, crawl, homers, xvi, canoes, sabotage, flensburg,
# Nearest to only: bbb, places, goidelic, customer, tp, frobisher, ortelius, rolland,
# Nearest to these: armageddon, infty, tremolo, witte, tats, path, theos, catalytic,
# Nearest to which: impress, fraction, vantaa, chapels, dido, mundo, rondo, inconsequential,
# Nearest to the: euros, asa, golfo, their, diphthongs, tribesmen, follows, paternity,
# Nearest to his: hairless, gaines, lomography, kh, tropic, spiritualism, taira, mandel,
# Nearest to an: dramas, altruism, acceptor, dekker, silas, traveled, testifying, badajoz,
# Nearest to three: lessens, suvs, forays, instant, sorcery, crosstown, mutinied, rossellini,
# Nearest to as: clowns, heartbroken, blanton, delight, transgenic, installation, shin, cardinality,
# Nearest to history: feedstock, mexica, heliports, sars, christ, jujutsu, hospitalization, gtpases,
# Nearest to used: zheng, eubulides, jell, rocketry, earl, insurgency, salvation, tackling,
# Average loss at step 2000: 4.370080
# Average loss at step 4000: 3.861786
# Average loss at step 6000: 3.786239
# Average loss at step 8000: 3.690706
# Average loss at step 10000: 3.619699
# Nearest to d: poetess, harbors, catalyzed, modena, vodka, amigas, exponentially, hercule,
# Nearest to from: by, palatinate, cts, into, promotional, in, of, for,
# Nearest to s: his, and, hercule, misrepresented, cartridges, or, lfheim, coens,
# Nearest to he: it, she, they, who, elijah, commutators, edmund, pitched,
# Nearest to more: adair, billion, freeciv, legacies, interpretative, recruited, concretely, most,
# Nearest to war: runge, crawl, peppers, homers, dedication, woefully, sabotage, reestablishment,
# Nearest to only: bbb, customer, rolland, goidelic, places, guerrero, matlab, belarusians,
# Nearest to these: armageddon, references, infty, theos, disaster, laws, interlude, halfway,
# Nearest to which: this, that, also, it, chapels, desks, however, rondo,
# Nearest to the: a, this, its, his, their, burghers, patricio, an,
# Nearest to his: their, her, the, its, grape, s, bloomsbury, parthian,
# Nearest to an: the, rieure, identity, dramas, silas, crudely, kohlrabi, pan,
# Nearest to three: four, five, eight, six, two, seven, nine, zero,
# Nearest to as: juanita, latina, be, unavailable, clowns, atlases, weapon, digital,
# Nearest to history: mexica, sars, christ, heliports, cumin, incriminating, feedstock, grab,
# Nearest to used: zheng, referred, eubulides, fukuyama, hagen, rocketry, armistice, philos,
# Average loss at step 12000: 3.603403
# Average loss at step 14000: 3.570480
# Average loss at step 16000: 3.408300
# Average loss at step 18000: 3.457127
# Average loss at step 20000: 3.538576
# Nearest to d: b, harbors, catalyzed, hercule, poetess, modena, exponentially, preprocessing,
# Nearest to from: into, at, palatinate, cts, in, and, for, by,
# Nearest to s: bobby, deny, coens, updating, faq, generalize, maturation, lonnie,
# Nearest to he: it, she, they, who, there, resinous, agp, esoteric,
# Nearest to more: less, most, adair, very, recruited, legacies, bravely, saumur,
# Nearest to war: runge, crawl, sabotage, northeastern, hovercraft, woefully, peppers, homers,
# Nearest to only: beyond, guerrero, rolland, it, gepids, lovejoy, openvms, eicher,
# Nearest to these: some, such, many, which, their, both, disaster, armageddon,
# Nearest to which: that, this, also, it, but, these, there, desks,
# Nearest to the: their, its, this, riverfront, his, descending, a, associates,
# Nearest to his: their, her, its, the, anglicisation, lugs, cdm, parthian,
# Nearest to an: crudely, pan, acceptor, the, rieure, immense, altruism, dramas,
# Nearest to three: five, four, seven, six, two, eight, nine, zero,
# Nearest to as: logical, buddy, guantanamo, juanita, spaced, horsemanship, unavailable, vim,
# Nearest to history: mexica, stead, sars, cumin, incriminating, result, missal, christ,
# Nearest to used: zheng, referred, known, found, eubulides, roofed, fukuyama, armistice,
# Average loss at step 22000: 3.505025
# Average loss at step 24000: 3.490189
# Average loss at step 26000: 3.484641
# Average loss at step 28000: 3.480772
# Average loss at step 30000: 3.505041
# Nearest to d: b, catalyzed, modena, hercule, preprocessing, exponentially, neighbour, poetess,
# Nearest to from: into, palatinate, in, cts, between, after, through, by,
# Nearest to s: and, his, maturation, misrepresented, cartridges, hercule, transsexualism, dread,
# Nearest to he: she, it, they, who, there, never, conspirator, pitched,
# Nearest to more: less, most, very, smaller, bravely, melee, rather, floppies,
# Nearest to war: runge, crawl, sabotage, hovercraft, curlers, trafalgar, browed, flensburg,
# Nearest to only: beyond, gepids, credited, rolland, did, upstate, matlab, guerrero,
# Nearest to these: some, many, such, both, their, they, which, various,
# Nearest to which: this, that, also, it, these, who, desks, what,
# Nearest to the: its, their, his, a, this, some, burghers, pivotal,
# Nearest to his: her, their, its, the, your, grape, s, my,
# Nearest to an: rieure, crudely, dramas, altruism, legislation, kohlrabi, lager, lansbury,
# Nearest to three: five, four, six, seven, eight, two, nine, zero,
# Nearest to as: by, became, cryptosystems, when, couples, respectability, or, sava,
# Nearest to history: username, mexica, stead, cumin, result, peacetime, incriminating, riverside,
# Nearest to used: known, referred, represented, seen, zheng, found, written, regarded,
# Average loss at step 32000: 3.500115
# Average loss at step 34000: 3.491600
# Average loss at step 36000: 3.454758
# Average loss at step 38000: 3.304860
# Average loss at step 40000: 3.432965
# Nearest to d: b, catalyzed, UNK, roping, modena, neighbour, abet, exponentially,
# Nearest to from: into, through, cts, palatinate, under, for, in, between,
# Nearest to s: his, topless, andaman, maturation, deficits, her, cartridges, pfaff,
# Nearest to he: she, it, they, who, there, i, we, resinous,
# Nearest to more: less, most, very, smaller, quite, saumur, bravely, floppies,
# Nearest to war: runge, crawl, sabotage, vacated, northeastern, peppers, erc, larson,
# Nearest to only: credited, servius, fairly, even, first, lovejoy, dying, it,
# Nearest to these: some, many, both, several, they, such, those, various,
# Nearest to which: this, that, also, usually, who, it, often, there,
# Nearest to the: their, a, this, his, its, any, bbci, another,
# Nearest to his: her, their, its, your, the, s, my, grape,
# Nearest to an: rieure, crudely, altruism, hoosier, dramas, intentional, unital, hoplite,
# Nearest to three: four, five, two, seven, six, eight, zero, nine,
# Nearest to as: when, guantanamo, speedily, by, logical, latina, violin, overnight,
# Nearest to history: encyclopedia, username, stead, list, riverside, mexica, result, incriminating,
# Nearest to used: known, seen, referred, found, represented, regarded, designed, considered,
# Average loss at step 42000: 3.433220
# Average loss at step 44000: 3.455944
# Average loss at step 46000: 3.452844
# Average loss at step 48000: 3.352599
# Average loss at step 50000: 3.380149
# Nearest to d: b, h, g, p, florence, catalyzed, abet, schneier,
# Nearest to from: through, palatinate, into, in, cts, cortes, barbaric, between,
# Nearest to s: maturation, whose, his, misrepresented, your, hercule, betty, and,
# Nearest to he: she, it, they, who, there, soon, then, meanwhile,
# Nearest to more: less, most, very, quite, smaller, bravely, fairly, rather,
# Nearest to war: runge, crawl, sabotage, peppers, vacated, regulars, kapellmeister, canadians,
# Nearest to only: first, typically, even, interactively, dying, seraphim, always, actually,
# Nearest to these: some, many, both, such, several, various, their, those,
# Nearest to which: this, that, also, who, usually, what, often, however,
# Nearest to the: its, their, this, his, any, some, a, another,
# Nearest to his: their, her, its, my, your, the, grape, our,
# Nearest to an: rieure, no, lager, ment, altruism, crudely, the, unital,
# Nearest to three: four, six, five, seven, eight, two, nine, zero,
# Nearest to as: wick, sava, chunk, specially, astrometry, spinal, clusters, clockwork,
# Nearest to history: encyclopedia, username, list, cramped, chymotrypsin, mexica, result, rambling,
# Nearest to used: known, referred, seen, written, represented, designed, understood, found,
# Average loss at step 52000: 3.437699
# Average loss at step 54000: 3.427774
# Average loss at step 56000: 3.436221
# Average loss at step 58000: 3.396271
# Average loss at step 60000: 3.393675
# Nearest to d: b, h, florence, missa, g, l, r, catalyzed,
# Nearest to from: into, through, palatinate, cts, cortes, after, in, under,
# Nearest to s: herald, raids, worshippers, whose, maturation, dischord, bassoonist, misrepresented,
# Nearest to he: she, it, they, who, there, never, soon, later,
# Nearest to more: less, rather, most, smaller, fairly, very, quite, larger,
# Nearest to war: runge, crawl, sabotage, vacated, peppers, regulars, flensburg, woefully,
# Nearest to only: first, until, always, typically, actually, never, even, still,
# Nearest to these: many, some, such, both, several, those, they, all,
# Nearest to which: that, this, what, usually, who, however, but, it,
# Nearest to the: their, a, its, some, this, descending, his, these,
# Nearest to his: her, their, its, my, grape, your, our, the,
# Nearest to an: rieure, nag, kohlrabi, unital, crudely, stereotypical, wes, altruism,
# Nearest to three: five, four, six, eight, two, seven, nine, zero,
# Nearest to as: wick, moroni, limburgish, frustrations, respectability, chunk, became, homily,
# Nearest to history: list, username, encyclopedia, cramped, dictionary, rambling, demographics, development,
# Nearest to used: seen, known, referred, designed, written, represented, found, understood,
# Average loss at step 62000: 3.231464
# Average loss at step 64000: 3.255258
# Average loss at step 66000: 3.408032
# Average loss at step 68000: 3.396645
# Average loss at step 70000: 3.363131
# Nearest to d: b, h, catalyzed, missa, florence, roping, neighbour, viii,
# Nearest to from: through, into, palatinate, in, cts, between, by, within,
# Nearest to s: topless, whose, angelica, synclavier, maturation, isbn, longrightarrow, pfaff,
# Nearest to he: she, it, they, who, there, soon, we, later,
# Nearest to more: less, most, very, rather, fairly, quite, smaller, larger,
# Nearest to war: runge, crawl, flensburg, sabotage, woefully, vacated, canadians, wars,
# Nearest to only: typically, actually, still, always, dying, never, first, until,
# Nearest to these: such, some, many, various, several, those, are, their,
# Nearest to which: that, this, usually, what, also, but, and, who,
# Nearest to the: their, its, any, a, this, these, or, another,
# Nearest to his: her, their, its, my, your, grape, our, zog,
# Nearest to an: unital, nag, rieure, altruism, crudely, wes, lager, kohlrabi,
# Nearest to three: four, six, five, two, seven, eight, nine, zero,
# Nearest to as: when, like, assign, create, euclidean, for, guantanamo, zuma,
# Nearest to history: list, encyclopedia, username, cramped, development, dictionary, zion, yarn,
# Nearest to used: seen, known, referred, written, found, represented, designed, understood,
# Average loss at step 72000: 3.380304
# Average loss at step 74000: 3.346838
# Average loss at step 76000: 3.318925
# Average loss at step 78000: 3.351327
# Average loss at step 80000: 3.378800
# Nearest to d: b, h, p, missa, schneier, neighbour, mwali, g,
# Nearest to from: through, into, palatinate, cortes, within, after, cts, in,
# Nearest to s: leste, disestablished, espouses, jerzy, isbn, capacitive, own, leyland,
# Nearest to he: she, it, they, there, who, we, resinous, eventually,
# Nearest to more: less, most, very, rather, quite, smaller, fairly, larger,
# Nearest to war: crawl, runge, wars, flensburg, woefully, regulars, throes, cession,
# Nearest to only: actually, first, always, until, dying, either, warp, therefore,
# Nearest to these: several, some, various, many, such, both, those, they,
# Nearest to which: this, that, patriarchy, usually, also, these, what, who,
# Nearest to the: its, their, this, his, a, projectors, rz, shenouda,
# Nearest to his: her, their, my, its, your, our, grape, the,
# Nearest to an: rieure, nag, wes, stint, altruism, crudely, shave, unital,
# Nearest to three: four, five, six, seven, two, eight, nine, zero,
# Nearest to as: speedily, quantized, cohabitation, wick, chunk, like, including, dressage,
# Nearest to history: list, encyclopedia, development, username, regardless, westphalia, cybele, sideband,
# Nearest to used: referred, known, seen, sold, written, represented, defined, designed,
# Average loss at step 82000: 3.410157
# Average loss at step 84000: 3.412423
# Average loss at step 86000: 3.386431
# Average loss at step 88000: 3.353503
# Average loss at step 90000: 3.368125
# Nearest to d: b, h, poetess, indepth, harbors, august, florence, distillers,
# Nearest to from: through, into, cortes, palatinate, cts, straightforward, before, after,
# Nearest to s: whose, mal, stunned, topless, his, cics, summand, her,
# Nearest to he: she, it, they, there, later, who, resinous, soon,
# Nearest to more: less, very, rather, most, quite, fairly, highly, better,
# Nearest to war: runge, wars, crawl, flensburg, kohlrabi, sabotage, zwingli, cession,
# Nearest to only: even, dying, actually, always, no, still, forgeries, not,
# Nearest to these: several, some, many, such, various, are, they, which,
# Nearest to which: that, this, also, what, usually, these, but, who,
# Nearest to the: its, their, his, a, this, each, another, geyser,
# Nearest to his: her, their, its, my, your, our, the, anglicisation,
# Nearest to an: altruism, rieure, crudely, gunner, unital, hoosier, kohlrabi, nag,
# Nearest to three: two, five, four, eight, seven, six, nine, zero,
# Nearest to as: dressage, eastman, chunk, cohabitation, crowe, speedily, hijacker, including,
# Nearest to history: list, encyclopedia, username, cramped, regardless, development, fainter, riverside,
# Nearest to used: referred, known, seen, designed, sold, represented, regarded, understood,
# Average loss at step 92000: 3.397884
# Average loss at step 94000: 3.255740
# Average loss at step 96000: 3.358340
# Average loss at step 98000: 3.243921
# Average loss at step 100000: 3.356046
# Nearest to d: b, h, roping, poetess, florence, august, catalyzed, neighbour,
# Nearest to from: through, in, into, cortes, palatinate, cts, within, during,
# Nearest to s: his, whose, stunned, your, bobby, browning, trampoline, maturation,
# Nearest to he: she, it, they, who, there, we, never, soon,
# Nearest to more: less, very, most, fairly, rather, quite, highly, better,
# Nearest to war: runge, wars, crawl, flensburg, hovercraft, cession, kohlrabi, kapellmeister,
# Nearest to only: even, exactly, not, still, always, combined, actually, amorites,
# Nearest to these: several, many, some, those, various, all, which, instead,
# Nearest to which: that, this, usually, what, these, actually, also, it,
# Nearest to the: their, its, his, your, a, this, each, some,
# Nearest to his: her, their, my, your, its, our, the, s,
# Nearest to an: altruism, unital, nag, cataloging, pediatric, gunner, crudely, another,
# Nearest to three: four, two, five, eight, seven, six, zero, nine,
# Nearest to as: like, astrometry, speedily, became, after, ez, commitments, marcos,
# Nearest to history: list, encyclopedia, username, sherwood, historical, yarn, menelik, regardless,
# Nearest to used: referred, sold, designed, known, found, seen, held, defined,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
