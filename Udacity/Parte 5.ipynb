# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'of', 'term', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.767453
# Nearest to it: reflective, interlocking, homeric, trophies, slash, aeon, stripe, functions,
# Nearest to for: asterix, upstart, brought, necessity, laymen, hussites, carnap, antiretroviral,
# Nearest to he: correcting, teeth, suspends, cryptographic, electricity, armand, lughnasadh, entomology,
# Nearest to three: cocalus, split, organs, dedicated, stepped, tor, camelcase, midpoint,
# Nearest to in: trivia, fanon, instituting, offering, cs, ricardian, evangelicalism, inertial,
# Nearest to UNK: launcher, amide, inexplicably, theorizing, croesus, donoghue, icing, delocalised,
# Nearest to such: ploughing, bricklin, batteries, sinus, bius, ili, bsd, strafford,
# Nearest to when: zh, memorization, crack, investigators, sdk, rote, yevgeny, doubtless,
# Nearest to only: ubiquitous, sportsmanship, demoralized, laughlin, nukem, gripping, influenza, finds,
# Nearest to from: qaddafi, heraldic, almost, centralizing, aside, semivowel, indigo, byelorussia,
# Nearest to this: surat, plugboard, cretaceous, vater, avidly, nsg, frets, maneuvered,
# Nearest to or: aristocrat, colbert, potable, surprise, topologically, photius, shek, amphetamines,
# Nearest to history: tomino, boxed, rotary, teimanim, onboard, scopes, krantz, octahedron,
# Nearest to may: baden, shackleton, rig, peppers, calculator, cumings, lovely, allocations,
# Nearest to see: socialize, zermelo, segregated, cleverly, carmelites, viscous, anorexia, sloan,
# Nearest to into: starbucks, tufts, bithynia, ambulatory, turkish, bach, mellon, wye,
# Average loss at step 2000: 4.378613
# Average loss at step 4000: 3.864449
# Average loss at step 6000: 3.795272
# Average loss at step 8000: 3.692447
# Average loss at step 10000: 3.619189
# Nearest to it: he, this, there, not, they, which, she, warping,
# Nearest to for: of, unintentionally, with, in, reciprocate, primary, smoke, irons,
# Nearest to he: it, she, they, who, perturbed, never, eminence, widely,
# Nearest to three: four, seven, five, six, two, eight, nine, zero,
# Nearest to in: of, at, on, and, against, with, vg, mu,
# Nearest to UNK: brutus, hackett, detractors, qc, de, victors, downplay, levine,
# Nearest to such: batteries, marches, bius, sinus, strafford, zoff, dissolves, cultural,
# Nearest to when: homomorphism, had, thuringiensis, zh, mismatch, mayall, yevgeny, hypothesis,
# Nearest to only: calligraphy, will, gripping, regained, emf, hear, brubeck, sigma,
# Nearest to from: into, by, in, bitumen, urbanized, amathus, warns, on,
# Nearest to this: it, the, which, a, his, iris, that, amalthea,
# Nearest to or: and, than, modena, fines, with, centaurus, web, s,
# Nearest to history: lens, asin, boxed, tomino, crowded, octahedron, defun, gypsum,
# Nearest to may: can, will, pyre, must, would, increased, should, baden,
# Nearest to see: socialize, zermelo, wisely, carmelites, zoologists, incarcerated, hotels, arecibo,
# Nearest to into: from, atmospheric, starbucks, oncoming, turkish, stigma, maulana, minting,
# Average loss at step 12000: 3.605225
# Average loss at step 14000: 3.567414
# Average loss at step 16000: 3.413153
# Average loss at step 18000: 3.456610
# Average loss at step 20000: 3.542456
# Nearest to it: he, there, this, they, she, which, not, no,
# Nearest to for: of, with, hms, by, colouring, and, primary, as,
# Nearest to he: it, she, they, who, there, never, then, slr,
# Nearest to three: four, two, seven, six, five, eight, one, nine,
# Nearest to in: at, on, with, from, amaranthus, and, mu, by,
# Nearest to UNK: levine, theorizing, detractors, police, graduation, bats, e, swept,
# Nearest to such: well, these, batteries, marches, known, additional, lightly, zebu,
# Nearest to when: homomorphism, after, where, was, at, priestly, spurious, thuringiensis,
# Nearest to only: calligraphy, meta, gripping, finds, brubeck, never, fathered, regained,
# Nearest to from: into, in, by, at, to, after, against, dictatorships,
# Nearest to this: it, which, the, a, there, iwerks, dativus, that,
# Nearest to or: and, than, modena, but, erroneous, espouse, syndication, to,
# Nearest to history: asin, lens, crowded, octahedron, ilo, ambulatory, defun, gypsum,
# Nearest to may: can, would, will, could, should, must, pyre, godard,
# Nearest to see: wisely, incarcerated, carmelites, kabir, socialize, reachable, arecibo, hotels,
# Nearest to into: from, atmospheric, against, dope, stigma, alcohols, studying, enters,
# Average loss at step 22000: 3.501716
# Average loss at step 24000: 3.486319
# Average loss at step 26000: 3.481548
# Average loss at step 28000: 3.473809
# Average loss at step 30000: 3.506037
# Nearest to it: he, there, she, this, they, generally, not, also,
# Nearest to for: of, primary, reciprocate, if, when, to, unintentionally, after,
# Nearest to he: she, it, they, who, there, never, perturbed, pastures,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to in: on, throughout, at, during, from, of, under, with,
# Nearest to UNK: boniface, individualistic, subtractive, martyr, serenity, wabash, van, regimen,
# Nearest to such: well, these, known, batteries, spacewalks, lightly, pyotr, zebu,
# Nearest to when: where, if, before, after, was, while, homomorphism, though,
# Nearest to only: calligraphy, typically, meta, aim, regained, courtesan, never, arguably,
# Nearest to from: into, in, dictatorships, suprema, between, bulwer, through, fiddle,
# Nearest to this: which, it, that, reborn, what, assays, adv, every,
# Nearest to or: and, gambier, oe, but, than, traditional, modena, sharing,
# Nearest to history: crowded, asin, octahedron, ambulatory, defun, ilo, lens, gypsum,
# Nearest to may: can, would, will, could, must, should, might, pyre,
# Nearest to see: wisely, incarcerated, concr, reachable, roald, carmelites, arecibo, hotels,
# Nearest to into: from, against, under, stigma, alcohols, with, dope, enters,
# Average loss at step 32000: 3.503943
# Average loss at step 34000: 3.492691
# Average loss at step 36000: 3.454135
# Average loss at step 38000: 3.307118
# Average loss at step 40000: 3.430470
# Nearest to it: he, there, she, they, this, which, then, koala,
# Nearest to for: in, of, colouring, when, astrologically, if, reciprocate, allergies,
# Nearest to he: she, it, they, there, who, i, we, nutmeg,
# Nearest to three: four, five, two, six, seven, eight, nine, zero,
# Nearest to in: of, from, on, during, for, within, at, and,
# Nearest to UNK: reconsideration, h, b, d, der, footprint, johnson, anxieties,
# Nearest to such: well, known, these, lightly, including, spacewalks, pyotr, batteries,
# Nearest to when: if, where, before, while, after, priestly, with, by,
# Nearest to only: calligraphy, meta, plebiscite, arguably, never, mallow, deadly, beli,
# Nearest to from: into, in, through, of, by, mckenna, under, hlich,
# Nearest to this: which, it, the, that, another, reborn, synapse, certify,
# Nearest to or: and, than, theorizes, but, modena, panoramic, a, technologically,
# Nearest to history: asin, stadtholder, list, mentored, laughs, science, defun, bibliography,
# Nearest to may: can, would, will, could, must, should, might, lavender,
# Nearest to see: roald, reachable, wisely, incarcerated, known, canmore, hotels, concr,
# Nearest to into: from, stigma, out, alcohols, oncoming, dope, enters, under,
# Average loss at step 42000: 3.433656
# Average loss at step 44000: 3.453951
# Average loss at step 46000: 3.452308
# Average loss at step 48000: 3.351532
# Average loss at step 50000: 3.380571
# Nearest to it: he, there, she, this, they, then, monarchical, generally,
# Nearest to for: while, colouring, from, in, plutinos, including, if, reciprocate,
# Nearest to he: she, it, they, there, who, vassals, dylan, dorsal,
# Nearest to three: four, seven, six, eight, five, two, nine, zero,
# Nearest to in: within, from, on, throughout, during, of, since, at,
# Nearest to UNK: buchanan, mclachlan, grands, et, dilmun, vdc, heinz, acetic,
# Nearest to such: well, these, known, batteries, many, lightly, pyotr, serve,
# Nearest to when: where, if, after, while, before, but, though, during,
# Nearest to only: meta, plebiscite, otherwise, calligraphy, fathered, since, always, mallow,
# Nearest to from: into, through, in, by, and, mckenna, for, attaching,
# Nearest to this: which, it, the, some, that, thorne, clashes, sprayed,
# Nearest to or: and, than, but, gambier, theoretic, vigilantes, replicator, hydrocodone,
# Nearest to history: asin, aac, mentored, list, sieges, stadtholder, artemisia, xii,
# Nearest to may: can, would, must, could, should, will, might, lavender,
# Nearest to see: concr, wisely, canmore, roald, arecibo, incarcerated, hotels, chisinau,
# Nearest to into: from, through, under, stigma, out, warns, dope, alcohols,
# Average loss at step 52000: 3.441841
# Average loss at step 54000: 3.432289
# Average loss at step 56000: 3.438747
# Average loss at step 58000: 3.397663
# Average loss at step 60000: 3.391076
# Nearest to it: he, there, she, this, they, usually, which, assays,
# Nearest to for: of, when, reciprocate, liang, colouring, including, functioned, if,
# Nearest to he: she, it, they, who, there, we, never, dylan,
# Nearest to three: four, five, six, eight, two, seven, nine, zero,
# Nearest to in: within, during, throughout, among, at, sloped, of, until,
# Nearest to UNK: unsigned, stressing, galilean, redman, bypasses, graphene, advantages, include,
# Nearest to such: known, many, well, these, pyotr, serve, batteries, including,
# Nearest to when: if, before, after, while, where, though, during, although,
# Nearest to only: plebiscite, arguably, nostrils, first, always, mallow, typically, otherwise,
# Nearest to from: through, into, within, dictatorships, slavic, in, geometric, franken,
# Nearest to this: which, it, that, there, what, the, some, dativus,
# Nearest to or: and, than, standout, motorists, but, theorizes, replicator, hydrocodone,
# Nearest to history: list, politics, studies, origins, irrevocably, pittsburg, term, treaty,
# Nearest to may: can, would, will, must, could, should, might, lavender,
# Nearest to see: include, wisely, but, external, byrnes, impotence, can, rigoletto,
# Nearest to into: through, from, under, within, adapts, with, against, stigma,
# Average loss at step 62000: 3.239615
# Average loss at step 64000: 3.254736
# Average loss at step 66000: 3.402788
# Average loss at step 68000: 3.395307
# Average loss at step 70000: 3.357593
# Nearest to it: he, there, she, this, they, usually, generally, still,
# Nearest to for: reciprocate, while, to, honorary, plutinos, colouring, including, liang,
# Nearest to he: she, it, they, there, we, who, brno, yakuza,
# Nearest to three: four, two, six, five, seven, eight, nine, zero,
# Nearest to in: within, on, during, through, throughout, from, until, between,
# Nearest to UNK: coliseum, involve, somehow, keeper, pinyin, boson, fab, seasoned,
# Nearest to such: these, many, known, well, some, certain, severn, pyotr,
# Nearest to when: if, before, where, while, though, after, although, during,
# Nearest to only: arguably, always, plebiscite, never, courtesan, lead, meta, mallow,
# Nearest to from: through, into, within, in, via, by, slavic, between,
# Nearest to this: which, it, that, the, what, some, certify, coy,
# Nearest to or: and, than, zambian, like, breached, without, but, gambier,
# Nearest to history: list, studies, irrevocably, asin, origins, politics, stadtholder, culture,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to see: rigoletto, external, byrnes, list, include, references, impotence, antonin,
# Nearest to into: from, through, within, under, adapts, in, between, dope,
# Average loss at step 72000: 3.375067
# Average loss at step 74000: 3.350863
# Average loss at step 76000: 3.317486
# Average loss at step 78000: 3.353725
# Average loss at step 80000: 3.379892
# Nearest to it: he, she, there, this, itself, they, usually, still,
# Nearest to for: ytterbium, reciprocate, honorary, entails, axiomatization, amu, colouring, jacobian,
# Nearest to he: she, it, they, there, we, who, later, never,
# Nearest to three: six, four, five, seven, two, eight, nine, one,
# Nearest to in: within, during, on, at, until, throughout, through, under,
# Nearest to UNK: dr, brown, l, h, johnson, sir, graduation, hughes,
# Nearest to such: well, these, known, certain, severn, serve, regarded, many,
# Nearest to when: if, before, during, after, while, though, where, although,
# Nearest to only: arguably, plebiscite, always, meta, lead, calligraphy, prefectural, never,
# Nearest to from: through, into, via, usaf, dictatorships, va, suprema, in,
# Nearest to this: which, it, the, what, itself, certify, coy, frigates,
# Nearest to or: and, than, while, buoyed, theorizes, breached, sparked, trioxide,
# Nearest to history: list, asin, chamber, irrevocably, beirut, noting, mariners, morbid,
# Nearest to may: can, could, would, must, will, should, might, cannot,
# Nearest to see: external, but, byrnes, refer, references, include, gobind, sandy,
# Nearest to into: through, from, within, back, under, over, stigma, adapts,
# Average loss at step 82000: 3.407921
# Average loss at step 84000: 3.406842
# Average loss at step 86000: 3.389006
# Average loss at step 88000: 3.351964
# Average loss at step 90000: 3.363598
# Nearest to it: he, she, there, they, this, itself, usually, never,
# Nearest to for: of, including, reciprocate, colouring, when, while, catharism, honorary,
# Nearest to he: she, it, they, there, who, later, we, smith,
# Nearest to three: four, five, two, six, eight, seven, nine, zero,
# Nearest to in: within, during, under, of, on, at, throughout, between,
# Nearest to UNK: diy, performs, brutus, alliterative, amicus, et, mccullough, hank,
# Nearest to such: well, known, certain, these, severn, follows, serve, many,
# Nearest to when: if, while, before, after, though, where, although, during,
# Nearest to only: always, arguably, plebiscite, sag, reflexive, abandoned, koestler, hayek,
# Nearest to from: through, into, via, during, toward, before, under, by,
# Nearest to this: which, it, the, itself, some, what, another, reborn,
# Nearest to or: and, though, but, hydrocodone, breached, theorizes, firsthand, gentis,
# Nearest to history: list, bruised, origins, asin, sieges, dictionary, studies, mariners,
# Nearest to may: could, can, would, will, should, must, might, cannot,
# Nearest to see: external, references, sandy, refer, list, but, impotence, reformist,
# Nearest to into: from, through, within, under, back, adapts, between, around,
# Average loss at step 92000: 3.396739
# Average loss at step 94000: 3.252550
# Average loss at step 96000: 3.357309
# Average loss at step 98000: 3.247240
# Average loss at step 100000: 3.360096
# Nearest to it: he, she, this, there, they, nothing, which, often,
# Nearest to for: when, including, reciprocate, colouring, without, during, against, while,
# Nearest to he: she, it, they, there, we, who, never, vassals,
# Nearest to three: two, five, four, six, eight, seven, nine, zero,
# Nearest to in: during, within, throughout, until, on, from, schizophrenic, at,
# Nearest to UNK: theorizing, hughes, keeper, futuna, ko, introductory, hyphenated, fab,
# Nearest to such: known, well, certain, many, these, serve, follows, severn,
# Nearest to when: if, while, before, although, after, though, where, during,
# Nearest to only: plebiscite, always, never, otherwise, backdoor, properly, arguably, not,
# Nearest to from: through, into, in, via, attaching, dictatorships, by, bcs,
# Nearest to this: it, which, itself, another, the, what, some, he,
# Nearest to or: and, than, theorizes, microchip, ferris, buoyed, konstantin, coagulation,
# Nearest to history: list, bruised, origins, asin, consist, rao, elector, sieges,
# Nearest to may: can, could, should, will, would, must, might, cannot,
# Nearest to see: references, external, sandy, refer, refers, can, links, reformist,
# Nearest to into: through, from, within, under, adapts, back, around, between,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # problem

# %%
data_index = 0

def generate_batch_CBOW(batch_size, num_skips, skip_window):
    global data_index
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        labels[i, 0] = buffer[skip_window]
        targets_to_avoid = [ skip_window ]
        target = skip_window  # target label at the center of the buffer
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i, j] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(4, 2),(2, 1),(1, 1),(2, 3)]:
    data_index = 0
    batch, labels = generate_batch_CBOW(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [ [reverse_dictionary[bi] for bi in batch[i]] for i in range(8) ])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])

batch, labels = generate_batch_CBOW(batch_size=8, num_skips=4, skip_window=2)
print(batch)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: [['term', 'a', 'originated', 'anarchism'], ['of', 'as', 'originated', 'term'], ['as', 'of', 'abuse', 'a'], ['abuse', 'first', 'a', 'term'], ['of', 'first', 'used', 'term'], ['used', 'against', 'abuse', 'of'], ['early', 'abuse', 'against', 'first'], ['first', 'working', 'early', 'used']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with num_skips = 2 and skip_window = 1:
#     batch: [['as', 'anarchism'], ['a', 'originated'], ['as', 'term'], ['of', 'a'], ['abuse', 'term'], ['of', 'first'], ['abuse', 'used'], ['against', 'first']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 1 and skip_window = 1:
#     batch: [['as'], ['originated'], ['term'], ['a'], ['abuse'], ['of'], ['abuse'], ['against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with num_skips = 2 and skip_window = 3:
#     batch: [['originated', 'abuse'], ['as', 'originated'], ['a', 'as'], ['of', 'against'], ['used', 'early'], ['against', 'abuse'], ['early', 'abuse'], ['class', 'against']]
#     labels: ['a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early']
# [[    1     1   103 27350]
#  [27350   103     2   855]
#  [    2     1     3   855]
#  [  103     1     1     3]
#  [  103   855     1 15068]
#  [    0     3 15068   855]
#  [    2     0     3     1]
#  [15068     1     2     1]]

# %%
# *************** Word2vec version : CBOW ie find the target word given its context (ie the words surrounding it) ***************
# Input (one hot encoding) > Hidden layer (embedding as the mean of embeddings of the context words) > logit > softmax > Cross entropy using negative sampling (computing efficiency purpose)
# Pure linear model ie no non-linear activation function (in particular no ReLU nor sigmoid).

batch_size = 128
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many context words we use for a target word.

embedding_size = 128 # Dimension of the embedding vector (ie number of neurons of the hidden layer)

num_sampled = 64 # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))


graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable( tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Look up embeddings for inputs.
    #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    xx = np.tile(np.arange(batch_size),(num_skips,1)).swapaxes(0,1).reshape(batch_size*num_skips,1)
    yy = np.tile(np.arange(num_skips),(batch_size,1)).reshape(batch_size*num_skips,1)
    indices = np.hstack((xx,yy))

    train_dataset_reformated = tf.reshape(train_dataset,[batch_size*num_skips])
    ids = tf.SparseTensor(indices=indices, values=train_dataset_reformated, shape=[batch_size, num_skips])

    embed = tf.nn.embedding_lookup_sparse(embeddings, ids, None, combiner='mean')
    # Compute the softmax loss, using a sample of the negative labels each time.
    # This is a pure linear model (ie no ReLU nor sigmoid activation function).
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed, train_labels, num_sampled, vocabulary_size))

    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings. We use the cosine distance.
    # Enable to visually check the evolution of the 8 nearest neighbors of 16 fixed frequent words during the learning process.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm # Embeddings of ALL vocabulary words
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset) # Embeddings of 16 fixed words initially randomnly picked among the 100 most frequent words
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings)) # Scalar product between the 2 previously computed embeddings sets


num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_CBOW(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 10000 == 0:
            if step > 0:
                average_loss = average_loss / 10000 # The average loss is an estimate of the loss over the last 10000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        if step % 20000 == 0: # note that this is expensive (~20% slowdown if computed every 500 steps)
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                log = 'Nearest to %s:' % valid_word
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()


def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()


num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-ddffa7ce1640> in <module>()
#      40
#      41     train_dataset_reformated = tf.reshape(train_dataset,[batch_size*num_skips])
# ---> 42     ids = tf.SparseTensor(indices=indices, values=train_dataset_reformated, shape=[batch_size, num_skips])
#      43
#      44     embed = tf.nn.embedding_lookup_sparse(embeddings, ids, None, combiner='mean')
#
# TypeError: __init__() got an unexpected keyword argument 'shape'
