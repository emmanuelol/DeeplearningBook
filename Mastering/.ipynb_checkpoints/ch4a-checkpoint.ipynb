# %%
import os
import tensorflow as tf
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pylab import rcParams
import pandas as pd
import numpy as np
# Out:
# c:\users\ledra\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
DATASETSLIB_HOME = os.path.join(os.path.expanduser('~'),'dl-ts','datasetslib')

# %%
import sys
if not DATASETSLIB_HOME in sys.path:
    sys.path.append(DATASETSLIB_HOME)
# %reload_ext autoreload
# %autoreload 2
import datasetslib

# %%
from datasetslib import util as dsu
from datasetslib import nputil
datasetslib.datasets_root = os.path.join(os.path.expanduser('~'),'datasets')

# %%
from datasetslib.ptb import PTBSimple
ptb = PTBSimple()
# downloads data, converts words to ids, converts files to a list of ids
ptb.load_data()
print('Train :', ptb.part['train'][0:5])
print('Test: ', ptb.part['test'][0:5])
print('Valid: ', ptb.part['valid'][0:5])
print('Vocabulary Length = ', ptb.vocab_len)
# Out:
# Already exists: C:\Users\ledra\datasets\ptb-simple\simple-examples.tgz
# Train : [9970 9971 9972 9974 9975]
# Test:  [102  14  24  32 752]
# Valid:  [1132   93  358    5  329]
# Vocabulary Length =  10000

# %%
# windows settings
ptb.skip_window = 2
ptb.reset_index()
# in CBOW input is the context word and output is the target word
y_batch, x_batch = ptb.next_batch_cbow()

print('The CBOW pairs : context,target')
for i in range(5 * ptb.skip_window):
    print('(', [ptb.id2word[x_i] for x_i in x_batch[i]],
          ',', y_batch[i], ptb.id2word[y_batch[i]], ')')
# Out:
# The CBOW pairs : context,target
# ( ['aer', 'banknote', 'calloway', 'centrust'] , 9972 berlitz )
# ( ['banknote', 'berlitz', 'centrust', 'cluett'] , 9974 calloway )
# ( ['berlitz', 'calloway', 'cluett', 'fromstein'] , 9975 centrust )
# ( ['calloway', 'centrust', 'fromstein', 'gitano'] , 9976 cluett )
# ( ['centrust', 'cluett', 'gitano', 'guterman'] , 9980 fromstein )
# ( ['cluett', 'fromstein', 'guterman', 'hydro-quebec'] , 9981 gitano )
# ( ['fromstein', 'gitano', 'hydro-quebec', 'ipo'] , 9982 guterman )
# ( ['gitano', 'guterman', 'ipo', 'kia'] , 9983 hydro-quebec )
# ( ['guterman', 'hydro-quebec', 'kia', 'memotec'] , 9984 ipo )
# ( ['hydro-quebec', 'ipo', 'memotec', 'mlx'] , 9986 kia )

# %%
# skip-grams
ptb.skip_window = 2
ptb.reset_index()
# in skip-gram input is the target word and output is the context word
x_batch, y_batch = ptb.next_batch_sg()

print('The skip-gram pairs : target,context')
for i in range(5 * ptb.skip_window):
    print('(', x_batch[i], ptb.id2word[x_batch[i]],
          ',', y_batch[i], ptb.id2word[y_batch[i]], ')')
# Out:
# The skip-gram pairs : target,context
# ( 9972 berlitz , 9970 aer )
# ( 9972 berlitz , 9971 banknote )
# ( 9972 berlitz , 9974 calloway )
# ( 9972 berlitz , 9975 centrust )
# ( 9974 calloway , 9971 banknote )
# ( 9974 calloway , 9972 berlitz )
# ( 9974 calloway , 9975 centrust )
# ( 9974 calloway , 9976 cluett )
# ( 9975 centrust , 9972 berlitz )
# ( 9975 centrust , 9974 calloway )

# %%
valid_size = 8
x_valid = np.random.choice(valid_size * 10, valid_size, replace=False)
print('valid: ',x_valid)
# Out:
# valid:  [75 62  2 46  4 12 16 68]

# %% [markdown]
# # skip-gram with tensorflow

# %%
batch_size = 128
embedding_size = 128  
n_negative_samples = 64
ptb.skip_window=2

# %%
# clear the effects of previous sessions in the Jupyter Notebook
tf.reset_default_graph()

# %%
inputs=tf.placeholder(dtype=tf.int32,shape=[batch_size])
outputs=tf.placeholder(dtype=tf.int32,shape=[batch_size,1])
inputs_valid=tf.constant(x_valid,dtype=tf.int32)

# %%
# define embeddings matrix with vocab_len rows and embedding_size columns
# each row represents vectore representation or embedding of a word
# in the vocbulary

embed_dist = tf.random_uniform(shape=[ptb.vocab_len, embedding_size],
                               minval=-1.0,
                               maxval=1.0
                               )
embed_matrix = tf.Variable(embed_dist,
                           name='embed_matrix'
                           )
# define the embedding lookup table
# provides the embeddings of the word ids in the input tensor
embed_ltable = tf.nn.embedding_lookup(embed_matrix, inputs)

# %%
#define the embedding look up table
#provides the embeddings of the word ids in the input tensor
embed_ltable = tf.nn.embedding_lookup(embed_matrix, inputs)

# %%
# define noise-contrastive estimation (NCE) loss layer

nce_dist = tf.truncated_normal(shape=[ptb.vocab_len, embedding_size],
                               stddev=1.0 /
                               tf.sqrt(embedding_size * 1.0)
                               )
nce_w = tf.Variable(nce_dist)
nce_b = tf.Variable(tf.zeros(shape=[ptb.vocab_len]))

# %%
loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_w,
                                     biases=nce_b,
                                     labels=outputs,
                                     inputs=embed_ltable,
                                     num_sampled=n_negative_samples,
                                     num_classes=ptb.vocab_len
                                     )
                      )

# %%
# compute the cosine similarity between validation set sample and all embeddings
norm=tf.sqrt(tf.reduce_sum(tf.square(embed_matrix),1,keep_dims=True))
normalized_embeddings=embed_matrix/norm

# %%
embed_valid=tf.nn.embedding_lookup(normalized_embeddings,inputs_valid)

# %%
similarity=tf.matmul(embed_valid,normalized_embeddings,transpose_b=True)

# %%
n_epochs=10
learning_rate=0.9
n_batches = ptb.n_batches_wv()
optimizer=tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(loss)

# %%
with tf.Session() as tfs:
    tf.global_variables_initializer().run()
    for epoch in range(n_epochs):
        epoch_loss=0
        ptb.reset_index()
        for step in range(n_batches):
            x_batch,y_batch=ptb.next_batch_sg()
            y_batch=nputil.to2d(y_batch,unit_axis=1)
            feed_dict={inputs:x_batch,outputs:y_batch}
            _,batch_loss=tfs.run([optimizer,loss],feed_dict=feed_dict)
            epoch_loss+=batch_loss
        epoch_loss=epoch_loss/n_batches
        print('\n Average loss after epoch ', epoch, ' :', epoch_loss)
        
       
        # print closest words to validation set at end of every epoch
        similarity_scores = tfs.run(similarity)
        top_k = 5
        for i in range(valid_size):
            similar_words = (-similarity_scores[i, :]
                             ).argsort()[1:top_k + 1]
            similar_str = 'Similar to {0:}:'.format(
                ptb.id2word[x_valid[i]])
            for k in range(top_k):
                similar_str = '{0:} {1:},'.format(
                    similar_str, ptb.id2word[similar_words[k]])
            print(similar_str)
    final_embeddings = tfs.run(normalized_embeddings)
# Out:
#  Average loss after epoch  0  : 114.27257642990503
# Similar to two: has, commission, food, first, N,
# Similar to share: clobbered, by, under, wants, masson,
# Similar to <eos>: dry, in, the, u.s., exchange,
# Similar to were: trade, their, cents, of, american,
# Similar to of: million, and, fell, orders, month,
# Similar to $: fields, president, countries, early, be,
# Similar to on: vice, september, owners, end, mortgage,
# Similar to i: a, last, mr., craft, investors,
#
#  Average loss after epoch  1  : 49.14058682551751
# Similar to two: food, officials, commission, first, chairman,
# Similar to share: clobbered, wants, under, by, advertisers,
# Similar to <eos>: the, <unk>, dry, heavy, u.s.,
# Similar to were: trade, their, bidding, cents, five,
# Similar to of: once, and, orders, come, fell,
# Similar to $: fields, president, early, countries, management,
# Similar to on: vice, request, anticipated, owners, end,
# Similar to i: a, last, delivery, capture, mr.,
#
#  Average loss after epoch  2  : 28.747729061505733
# Similar to two: officials, food, commission, chairman, back,
# Similar to share: clobbered, wants, counterparts, under, canada,
# Similar to <eos>: the, <unk>, heavy, dry, beneficiaries,
# Similar to were: trade, bidding, enough, their, cents,
# Similar to of: once, fell, year-to-year, come, and,
# Similar to $: fields, countries, neither, president, sheet,
# Similar to on: vice, request, end, anticipated, owners,
# Similar to i: a, prototype, craft, last, delivery,
#
#  Average loss after epoch  3  : 19.797445385884014
# Similar to two: officials, food, commission, back, chairman,
# Similar to share: clobbered, wants, counterparts, canada, under,
# Similar to <eos>: the, <unk>, heavy, conduct, representative,
# Similar to were: trade, enough, bidding, queen, cents,
# Similar to of: once, fell, come, year-to-year, unfilled,
# Similar to $: fields, president, neither, countries, sheet,
# Similar to on: vice, anticipated, request, lack, end,
# Similar to i: prototype, craft, capture, a, delivery,
#
#  Average loss after epoch  4  : 13.705893819912886
# Similar to two: officials, food, fiber, back, commission,
# Similar to share: clobbered, wants, counterparts, canada, advertisers,
# Similar to <eos>: heavy, <unk>, conduct, the, spinoff,
# Similar to were: trade, bidding, enough, queen, cents,
# Similar to of: once, fell, year-to-year, come, raise,
# Similar to $: fields, sheet, neither, watched, occur,
# Similar to on: vice, lack, owners, anticipated, request,
# Similar to i: prototype, craft, capture, delivery, last,
#
#  Average loss after epoch  5  : 10.764798699281155
# Similar to two: officials, food, fiber, back, chairman,
# Similar to share: clobbered, wants, counterparts, canada, under,
# Similar to <eos>: heavy, beneficiaries, described, spinoff, conduct,
# Similar to were: trade, bidding, enough, queen, midnight,
# Similar to of: once, fell, year-to-year, lord, unfilled,
# Similar to $: fields, sheet, watched, occur, neither,
# Similar to on: vice, lack, owners, anticipated, request,
# Similar to i: prototype, craft, capture, delivery, regarded,
#
#  Average loss after epoch  6  : 8.642342396271534
# Similar to two: officials, food, fiber, back, chairman,
# Similar to share: clobbered, wants, counterparts, canada, ban,
# Similar to <eos>: heavy, conduct, beneficiaries, spinoff, representative,
# Similar to were: trade, bidding, enough, queen, midnight,
# Similar to of: once, fell, lord, unfilled, raise,
# Similar to $: fields, sheet, occur, watched, neither,
# Similar to on: vice, lack, anticipated, owners, request,
# Similar to i: prototype, craft, capture, delivery, regarded,
#
#  Average loss after epoch  7  : 7.0818294653525715
# Similar to two: officials, food, fiber, back, pc,
# Similar to share: clobbered, wants, counterparts, canada, ban,
# Similar to <eos>: heavy, spinoff, beneficiaries, conduct, fujitsu,
# Similar to were: trade, bidding, queen, enough, midnight,
# Similar to of: once, lord, fell, shortage, raise,
# Similar to $: fields, sheet, occur, watched, neither,
# Similar to on: vice, lack, anticipated, request, owners,
# Similar to i: prototype, craft, capture, delivery, regarded,
#
#  Average loss after epoch  8  : 5.743628695225104
# Similar to two: officials, food, fiber, back, environmental,
# Similar to share: clobbered, wants, counterparts, canada, ban,
# Similar to <eos>: spinoff, heavy, beneficiaries, conduct, representative,
# Similar to were: trade, queen, bidding, enough, midnight,
# Similar to of: once, lord, drivers, shortage, fell,
# Similar to $: fields, sheet, occur, watched, neither,
# Similar to on: vice, lack, anticipated, fiber, request,
# Similar to i: prototype, craft, capture, regarded, delivery,
#
#  Average loss after epoch  9  : 5.361006039075362
# Similar to two: officials, food, fiber, back, environmental,
# Similar to share: clobbered, wants, counterparts, canada, ban,
# Similar to <eos>: heavy, spinoff, conduct, beneficiaries, representative,
# Similar to were: trade, queen, bidding, enough, midnight,
# Similar to of: once, lord, bankers, shortage, unfilled,
# Similar to $: fields, sheet, occur, neither, watched,
# Similar to on: vice, lack, fiber, anticipated, request,
# Similar to i: prototype, craft, capture, regarded, delivery,

# %%
n_epochs = 100
learning_rate = 0.9

with tf.Session() as tfs:
    tf.global_variables_initializer().run()
    for epoch in range(n_epochs):
        epoch_loss=0
        ptb.reset_index()
        for step in range(n_batches):
            x_batch,y_batch=ptb.next_batch_sg()
            y_batch=nputil.to2d(y_batch,unit_axis=1)
            feed_dict={inputs:x_batch,outputs:y_batch}
            _,batch_loss=tfs.run([optimizer,loss],feed_dict=feed_dict)
            epoch_loss+=batch_loss
        epoch_loss=epoch_loss/n_batches
        print('\n Average loss after epoch ', epoch, ' :', epoch_loss)
        
       
        # print closest words to validation set at end of every epoch
        similarity_scores = tfs.run(similarity)
        top_k = 5
        for i in range(valid_size):
            similar_words = (-similarity_scores[i, :]
                             ).argsort()[1:top_k + 1]
            similar_str = 'Similar to {0:}:'.format(
                ptb.id2word[x_valid[i]])
            for k in range(top_k):
                similar_str = '{0:} {1:},'.format(
                    similar_str, ptb.id2word[similar_words[k]])
            print(similar_str)
# Out:
#  Average loss after epoch  0  : 114.10593996292505
# Similar to two: its, sector, currency, investment, import,
# Similar to share: orders, eastern, johnson, folks, india,
# Similar to <eos>: that, as, apple, the, $,
# Similar to were: come, posted, and, there, recently,
# Similar to of: with, $, people, more, funds,
# Similar to $: its, hero, month, at, of,
# Similar to on: <unk>, other, would, to, 's,
# Similar to i: <unk>, wiped, was, throughout, those,
#
#  Average loss after epoch  1  : 50.2955056031545
# Similar to two: sector, currency, investment, shore, computing,
# Similar to share: india, johnson, orders, funny, eastern,
# Similar to <eos>: that, the, as, be, said,
# Similar to were: posted, come, there, mirror, recently,
# Similar to of: people, $, ago, N, more,
# Similar to $: its, hero, month, countries, surge,
# Similar to on: <unk>, nations, would, other, dealers,
# Similar to i: throughout, wiped, robert, besides, distribution,
#
#  Average loss after epoch  2  : 28.107934485643337
# Similar to two: investment, currency, sector, computing, shore,
# Similar to share: india, johnson, funny, folks, eastern,
# Similar to <eos>: that, the, said, be, japanese,
# Similar to were: posted, come, there, mirror, tariff,
# Similar to of: people, the, inched, funds, N,
# Similar to $: its, hero, money-fund, month, surge,
# Similar to on: nations, would, dealers, other, dairy,
# Similar to i: throughout, wiped, besides, distribution, robert,
#
#  Average loss after epoch  3  : 19.46836522145149
# Similar to two: investment, pierre, currency, shore, replaced,
# Similar to share: india, funny, johnson, folks, eastern,
# Similar to <eos>: that, the, vice, outside, said,
# Similar to were: posted, come, mirror, there, tariff,
# Similar to of: people, the, trained, drop, inched,
# Similar to $: its, hero, money-fund, progress, surge,
# Similar to on: would, dealers, nations, dairy, clues,
# Similar to i: throughout, distribution, besides, robert, wiped,
#
#  Average loss after epoch  4  : 13.720550490495485
# Similar to two: pierre, investment, currency, shore, computing,
# Similar to share: india, funny, johnson, folks, pending,
# Similar to <eos>: that, <unk>, the, vice, said,
# Similar to were: posted, come, mirror, there, tariff,
# Similar to of: the, people, trained, inched, suppliers,
# Similar to $: its, hero, money-fund, progress, material,
# Similar to on: dealers, nations, would, <unk>, dairy,
# Similar to i: throughout, distribution, besides, accumulated, robert,
#
#  Average loss after epoch  5  : 10.82968848103132
# Similar to two: pierre, investment, currency, computing, replaced,
# Similar to share: india, funny, johnson, folks, pending,
# Similar to <eos>: that, <unk>, vice, outside, said,
# Similar to were: posted, come, mirror, there, tariff,
# Similar to of: trained, suppliers, inched, people, drop,
# Similar to $: its, money-fund, hero, material, progress,
# Similar to on: dealers, nations, would, <unk>, dairy,
# Similar to i: throughout, distribution, besides, accumulated, robert,
#
#  Average loss after epoch  6  : 9.001984122471931
# Similar to two: pierre, investment, currency, computing, replaced,
# Similar to share: india, funny, johnson, pending, folks,
# Similar to <eos>: that, <unk>, apple, said, invest,
# Similar to were: posted, come, mirror, there, priced,
# Similar to of: trained, inched, preferences, suppliers, people,
# Similar to $: money-fund, its, hero, material, progress,
# Similar to on: <unk>, dealers, nations, dairy, would,
# Similar to i: throughout, distribution, besides, accumulated, robert,
#
#  Average loss after epoch  7  : 6.635586908230414
# Similar to two: pierre, investment, replaced, computing, currency,
# Similar to share: india, funny, johnson, pending, folks,
# Similar to <eos>: that, invest, paul, said, just,
# Similar to were: posted, come, mirror, priced, there,
# Similar to of: trained, inched, preferences, suppliers, outlawed,
# Similar to $: money-fund, hero, its, material, progress,
# Similar to on: <unk>, dealers, dairy, nations, would,
# Similar to i: throughout, distribution, accumulated, besides, robert,
#
#  Average loss after epoch  8  : 6.1287985405860805
# Similar to two: pierre, investment, computing, replaced, shore,
# Similar to share: india, funny, johnson, pending, favored,
# Similar to <eos>: that, <unk>, independent, invest, paul,
# Similar to were: posted, come, mirror, priced, there,
# Similar to of: trained, inched, preferences, suppliers, outlawed,
# Similar to $: money-fund, hero, its, material, progress,
# Similar to on: dealers, dairy, nations, <unk>, would,
# Similar to i: throughout, distribution, accumulated, besides, robert,
#
#  Average loss after epoch  9  : 5.173401443622051
# Similar to two: pierre, replaced, computing, investment, shore,
# Similar to share: india, funny, pending, johnson, favored,
# Similar to <eos>: single-family, independent, paul, invest, vice,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: trained, inched, preferences, suppliers, outlawed,
# Similar to $: money-fund, hero, material, its, progress,
# Similar to on: dealers, dairy, nations, would, considering,
# Similar to i: throughout, distribution, accumulated, besides, robert,
#
#  Average loss after epoch  10  : 4.977037020218678
# Similar to two: pierre, replaced, computing, investment, shore,
# Similar to share: india, funny, pending, johnson, favored,
# Similar to <eos>: independent, single-family, paul, invest, vice,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: trained, inched, preferences, suppliers, outlawed,
# Similar to $: money-fund, hero, material, its, progress,
# Similar to on: dealers, dairy, nations, removed, sides,
# Similar to i: throughout, distribution, accumulated, besides, robert,
#
#  Average loss after epoch  11  : 4.5809494990568895
# Similar to two: pierre, replaced, computing, shore, investment,
# Similar to share: india, funny, pending, johnson, favored,
# Similar to <eos>: single-family, invest, independent, paul, apple,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: trained, inched, suppliers, preferences, outlawed,
# Similar to $: money-fund, hero, material, progress, its,
# Similar to on: dealers, dairy, nations, removed, sides,
# Similar to i: throughout, distribution, accumulated, besides, robert,
#
#  Average loss after epoch  12  : 4.436717651593379
# Similar to two: pierre, replaced, computing, shore, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, paul, independent, invest, free,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, trained, preferences, suppliers, outlawed,
# Similar to $: money-fund, hero, material, progress, its,
# Similar to on: dealers, dairy, nations, removed, sides,
# Similar to i: throughout, distribution, accumulated, besides, robert,
#
#  Average loss after epoch  13  : 4.0041846082760735
# Similar to two: pierre, replaced, computing, shore, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, independent, paul, invest, free,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, trained, suppliers, preferences, outlawed,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: dealers, dairy, nations, removed, sides,
# Similar to i: throughout, distribution, accumulated, besides, broader,
#
#  Average loss after epoch  14  : 4.009562918773065
# Similar to two: pierre, replaced, computing, shore, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, paul, independent, invest, free,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, trained, suppliers, preferences, outlawed,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: dealers, dairy, nations, removed, sides,
# Similar to i: throughout, distribution, accumulated, besides, broader,
#
#  Average loss after epoch  15  : 3.912008514771095
# Similar to two: pierre, replaced, shore, computing, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, paul, independent, invest, free,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, trained, suppliers, preferences, outlawed,
# Similar to $: money-fund, hero, material, progress, posted,
# Similar to on: dealers, dairy, nations, sides, removed,
# Similar to i: throughout, accumulated, distribution, besides, broader,
#
#  Average loss after epoch  16  : 3.835078756014506
# Similar to two: pierre, replaced, shore, computing, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, independent, paul, free, just,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, preferences, trained, suppliers, plunged,
# Similar to $: money-fund, hero, material, progress, posted,
# Similar to on: dealers, dairy, nations, sides, removed,
# Similar to i: throughout, accumulated, distribution, besides, broader,
#
#  Average loss after epoch  17  : 3.7629573299334598
# Similar to two: pierre, replaced, shore, computing, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, independent, paul, just, free,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, preferences, trained, suppliers, outlawed,
# Similar to $: money-fund, hero, material, progress, posted,
# Similar to on: dealers, dairy, sides, removed, attracts,
# Similar to i: throughout, accumulated, distribution, besides, broader,
#
#  Average loss after epoch  18  : 3.6791473573599105
# Similar to two: pierre, shore, replaced, computing, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, independent, paul, free, invest,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, preferences, suppliers, trained, lawyer,
# Similar to $: money-fund, hero, material, progress, posted,
# Similar to on: dealers, dairy, removed, sides, attracts,
# Similar to i: throughout, accumulated, distribution, besides, broader,
#
#  Average loss after epoch  19  : 3.613809191263639
# Similar to two: pierre, shore, replaced, computing, investment,
# Similar to share: india, funny, pending, favored, johnson,
# Similar to <eos>: single-family, independent, paul, free, just,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, lawyer,
# Similar to $: money-fund, hero, material, progress, show,
# Similar to on: dealers, dairy, removed, attracts, sides,
# Similar to i: throughout, accumulated, distribution, besides, broader,
#
#  Average loss after epoch  20  : 3.6092411814591823
# Similar to two: pierre, shore, computing, replaced, investment,
# Similar to share: india, funny, favored, pending, johnson,
# Similar to <eos>: single-family, independent, free, just, invest,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, trained, preferences, suppliers, lawyer,
# Similar to $: money-fund, hero, material, progress, show,
# Similar to on: dealers, dairy, removed, attracts, sides,
# Similar to i: throughout, accumulated, besides, distribution, broader,
#
#  Average loss after epoch  21  : 3.545070957679015
# Similar to two: pierre, shore, replaced, computing, investment,
# Similar to share: india, favored, pending, funny, johnson,
# Similar to <eos>: single-family, independent, free, paul, just,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, preferences, trained, suppliers, plunged,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: removed, dealers, attracts, dairy, sides,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  22  : 3.5667351881663003
# Similar to two: pierre, shore, computing, replaced, investment,
# Similar to share: india, favored, pending, funny, johnson,
# Similar to <eos>: single-family, independent, free, just, vice,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, preferences, suppliers, trained, lawyer,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: removed, dairy, attracts, dealers, sides,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  23  : 3.500896938336201
# Similar to two: pierre, shore, replaced, computing, investment,
# Similar to share: india, favored, pending, funny, johnson,
# Similar to <eos>: single-family, free, paul, just, independent,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, lawyer,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: attracts, removed, dairy, dealers, sides,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  24  : 3.4599076555325436
# Similar to two: pierre, shore, computing, replaced, investment,
# Similar to share: india, favored, pending, funny, johnson,
# Similar to <eos>: single-family, free, paul, independent, just,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, trained, preferences, century,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: attracts, removed, dealers, sides, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  25  : 3.4275471652165437
# Similar to two: pierre, shore, computing, replaced, investment,
# Similar to share: favored, india, pending, funny, johnson,
# Similar to <eos>: single-family, paul, independent, just, free,
# Similar to were: posted, mirror, come, priced, victor,
# Similar to of: inched, suppliers, preferences, trained, depositary,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: attracts, removed, dealers, sides, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  26  : 3.4739384192686815
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, johnson,
# Similar to <eos>: single-family, paul, free, just, independent,
# Similar to were: posted, mirror, come, priced, victor,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: money-fund, hero, material, progress, surge,
# Similar to on: removed, attracts, sides, dealers, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  27  : 3.3984612960081835
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, johnson,
# Similar to <eos>: single-family, free, independent, paul, just,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: money-fund, hero, material, surge, wildly,
# Similar to on: removed, attracts, sides, dealers, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  28  : 3.3491594470464268
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, johnson,
# Similar to <eos>: single-family, independent, free, just, paul,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: money-fund, hero, material, wildly, progress,
# Similar to on: attracts, removed, sides, dealers, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  29  : 3.3732138535915275
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, johnson,
# Similar to <eos>: single-family, free, just, independent, paul,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: money-fund, hero, material, wildly, progress,
# Similar to on: attracts, removed, sides, dealers, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  30  : 3.3397698410046406
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, details,
# Similar to <eos>: single-family, free, just, independent, working,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: money-fund, hero, material, wildly, progress,
# Similar to on: attracts, removed, sides, beneficiaries, dealers,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  31  : 3.322874915905488
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, details,
# Similar to <eos>: single-family, free, just, independent, stopped,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: money-fund, hero, material, wildly, progress,
# Similar to on: attracts, removed, sides, beneficiaries, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  32  : 3.289773477193637
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, india, pending, funny, details,
# Similar to <eos>: single-family, just, free, independent, stopped,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, lawyer,
# Similar to $: hero, money-fund, material, wildly, progress,
# Similar to on: attracts, removed, sides, beneficiaries, dairy,
# Similar to i: throughout, accumulated, besides, distribution, broader,
#
#  Average loss after epoch  33  : 3.310350927786949
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, paul, free, independent,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, trained, drop,
# Similar to $: hero, material, money-fund, wildly, progress,
# Similar to on: attracts, removed, sides, beneficiaries, agreement,
# Similar to i: throughout, accumulated, besides, distribution, broader,
#
#  Average loss after epoch  34  : 3.2684075641326413
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, free, independent, just, baseball,
# Similar to were: posted, mirror, priced, come, tariff,
# Similar to of: inched, suppliers, preferences, mirror, drop,
# Similar to $: hero, material, money-fund, wildly, progress,
# Similar to on: attracts, removed, sides, beneficiaries, dairy,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  35  : 3.2666074885771823
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, free, independent, paul,
# Similar to were: posted, mirror, come, priced, tariff,
# Similar to of: inched, suppliers, preferences, drop, mirror,
# Similar to $: hero, material, money-fund, wildly, surge,
# Similar to on: removed, attracts, sides, beneficiaries, join,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  36  : 3.2477950560740934
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, free, stopped, independent,
# Similar to were: posted, mirror, priced, come, tariff,
# Similar to of: inched, suppliers, preferences, drop, century,
# Similar to $: hero, material, money-fund, wildly, progress,
# Similar to on: attracts, removed, sides, beneficiaries, join,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  37  : 3.233848104874293
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, paul, stopped, free, just,
# Similar to were: posted, mirror, priced, come, tariff,
# Similar to of: inched, suppliers, preferences, drop, depositary,
# Similar to $: hero, material, money-fund, wildly, john,
# Similar to on: attracts, removed, beneficiaries, sides, join,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  38  : 3.226019479907476
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, free, stopped, baseball,
# Similar to were: posted, mirror, priced, come, tariff,
# Similar to of: inched, suppliers, preferences, drop, century,
# Similar to $: material, hero, money-fund, wildly, john,
# Similar to on: attracts, removed, join, sides, beneficiaries,
# Similar to i: throughout, besides, accumulated, distribution, broader,
#
#  Average loss after epoch  39  : 3.220422852115753
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, stopped, philippines, baseball,
# Similar to were: posted, mirror, priced, come, october,
# Similar to of: inched, suppliers, preferences, century, drop,
# Similar to $: material, hero, money-fund, wildly, surge,
# Similar to on: removed, attracts, beneficiaries, join, sides,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  40  : 3.2030875209050302
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, stopped, free, baseball,
# Similar to were: posted, mirror, priced, come, october,
# Similar to of: inched, suppliers, drop, preferences, estimated,
# Similar to $: material, hero, money-fund, wildly, john,
# Similar to on: removed, attracts, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  41  : 3.1800544689863157
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, stopped, relations, independent,
# Similar to were: posted, priced, mirror, come, october,
# Similar to of: inched, suppliers, drop, preferences, estimated,
# Similar to $: hero, material, money-fund, wildly, john,
# Similar to on: removed, attracts, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  42  : 3.174126827563995
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, stopped, just, paul, relations,
# Similar to were: posted, mirror, priced, come, october,
# Similar to of: inched, suppliers, preferences, drop, estimated,
# Similar to $: hero, material, money-fund, wildly, john,
# Similar to on: removed, attracts, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  43  : 3.1717083851496377
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, paul, stopped, philippines,
# Similar to were: posted, mirror, come, priced, october,
# Similar to of: inched, suppliers, preferences, estimated, drop,
# Similar to $: material, hero, money-fund, wildly, defeat,
# Similar to on: removed, attracts, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  44  : 3.1632488618294397
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, baseball, stopped, just, relations,
# Similar to were: posted, mirror, priced, come, october,
# Similar to of: inched, suppliers, drop, preferences, estimated,
# Similar to $: hero, material, money-fund, wildly, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  45  : 3.1505531783287344
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, stopped, just, baseball, paul,
# Similar to were: posted, mirror, priced, october, come,
# Similar to of: inched, suppliers, drop, estimated, preferences,
# Similar to $: hero, material, money-fund, john, wildly,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  46  : 3.154240997173847
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, baseball, stopped, free,
# Similar to were: posted, mirror, october, priced, come,
# Similar to of: inched, suppliers, drop, preferences, mirror,
# Similar to $: hero, material, money-fund, wildly, john,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, distribution, scrapped,
#
#  Average loss after epoch  47  : 3.131494551132887
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, stopped, working, vice,
# Similar to were: posted, mirror, october, priced, come,
# Similar to of: inched, suppliers, drop, estimated, preferences,
# Similar to $: material, hero, money-fund, john, wildly,
# Similar to on: removed, attracts, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  48  : 3.146269446764237
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, washington-based,
# Similar to <eos>: single-family, just, stopped, relations, philippines,
# Similar to were: posted, october, mirror, come, priced,
# Similar to of: inched, suppliers, drop, preferences, mirror,
# Similar to $: hero, material, money-fund, john, wildly,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  49  : 3.1253120471269655
# Similar to two: pierre, shore, computing, replaced, washington-based,
# Similar to share: favored, pending, india, funny, washington-based,
# Similar to <eos>: single-family, just, relations, stopped, philippines,
# Similar to were: posted, october, priced, come, mirror,
# Similar to of: inched, suppliers, drop, preferences, estimated,
# Similar to $: hero, material, money-fund, john, wildly,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  50  : 3.1272554794947305
# Similar to two: pierre, shore, computing, guaranteed, replaced,
# Similar to share: favored, pending, india, funny, details,
# Similar to <eos>: single-family, just, philippines, stopped, relations,
# Similar to were: posted, october, priced, mirror, come,
# Similar to of: inched, suppliers, preferences, drop, century,
# Similar to $: hero, material, money-fund, john, defeat,
# Similar to on: attracts, removed, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  51  : 3.1122650928222217
# Similar to two: pierre, shore, computing, washington-based, guaranteed,
# Similar to share: favored, pending, india, funny, duty-free,
# Similar to <eos>: single-family, just, relations, baseball, stopped,
# Similar to were: posted, october, priced, come, mirror,
# Similar to of: inched, suppliers, preferences, century, estimated,
# Similar to $: hero, material, money-fund, john, wildly,
# Similar to on: attracts, removed, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  52  : 3.0973417862103534
# Similar to two: pierre, shore, computing, washington-based, guaranteed,
# Similar to share: favored, pending, india, funny, washington-based,
# Similar to <eos>: single-family, just, stopped, baseball, working,
# Similar to were: posted, october, priced, mirror, come,
# Similar to of: inched, suppliers, drop, estimated, preferences,
# Similar to $: hero, material, john, money-fund, defeat,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  53  : 3.089067171781491
# Similar to two: pierre, shore, computing, washington-based, guaranteed,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, just, stopped, working, baseball,
# Similar to were: posted, october, priced, come, mirror,
# Similar to of: inched, suppliers, drop, mirror, preferences,
# Similar to $: hero, material, john, money-fund, defeat,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  54  : 3.084599961837133
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, duty-free, washington-based,
# Similar to <eos>: single-family, just, working, philippines, stopped,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, below, preferences,
# Similar to $: hero, material, john, money-fund, wildly,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  55  : 3.0709752092758813
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, just, stopped, philippines, relations,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, suppliers, drop, preferences, mirror,
# Similar to $: hero, material, john, money-fund, wildly,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  56  : 3.0701563381231747
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, just, relations, stopped, philippines,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, preferences, below,
# Similar to $: material, hero, john, money-fund, defeat,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  57  : 3.0729947854311037
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, chefs, washington-based,
# Similar to <eos>: single-family, relations, stopped, philippines, just,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, suppliers, drop, preferences, mirror,
# Similar to $: hero, material, john, money-fund, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  58  : 3.0409201161983686
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, relations, stopped, baseball, just,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, preferences, estimated,
# Similar to $: material, john, hero, money-fund, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  59  : 3.036476576557526
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, stopped, relations, just, baseball,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, suppliers, drop, below, estimated,
# Similar to $: material, john, money-fund, hero, wildly,
# Similar to on: removed, attracts, join, beneficiaries, sides,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  60  : 3.02938587925373
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, relations, baseball, stopped, just,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, drop, suppliers, preferences, estimated,
# Similar to $: material, john, hero, defeat, wildly,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  61  : 3.047017928881523
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, washington-based, chefs,
# Similar to <eos>: single-family, stopped, just, relations, baseball,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, mirror, estimated,
# Similar to $: john, material, hero, wildly, money-fund,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  62  : 3.0231567105421653
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, india, chefs, washington-based,
# Similar to <eos>: single-family, baseball, stopped, just, relations,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, suppliers, drop, estimated, preferences,
# Similar to $: john, material, hero, wildly, money-fund,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  63  : 3.0284916151028414
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, india, duty-free,
# Similar to <eos>: single-family, baseball, stopped, just, relations,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, century, estimated,
# Similar to $: john, material, hero, wildly, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  64  : 3.008760731953841
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, india,
# Similar to <eos>: single-family, stopped, baseball, just, relations,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, estimated, mirror,
# Similar to $: john, material, wildly, hero, defeat,
# Similar to on: removed, attracts, join, beneficiaries, requested,
# Similar to i: throughout, besides, accumulated, scrapped, distribution,
#
#  Average loss after epoch  65  : 3.0248757425027017
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, stopped, baseball, relations, just,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, suppliers, drop, estimated, below,
# Similar to $: john, hero, material, wildly, defeat,
# Similar to on: removed, attracts, join, beneficiaries, harmony,
# Similar to i: throughout, besides, scrapped, accumulated, distribution,
#
#  Average loss after epoch  66  : 3.0147349387407303
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, stopped, just, baseball, relations,
# Similar to were: posted, october, priced, come, lent,
# Similar to of: inched, suppliers, drop, mirror, below,
# Similar to $: john, wildly, hero, material, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, besides, accumulated, distribution,
#
#  Average loss after epoch  67  : 2.9918346198705525
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, india,
# Similar to <eos>: single-family, just, baseball, stopped, relations,
# Similar to were: posted, october, priced, advertised, come,
# Similar to of: inched, suppliers, drop, below, mirror,
# Similar to $: john, wildly, material, defeat, hero,
# Similar to on: removed, attracts, join, beneficiaries, harmony,
# Similar to i: throughout, scrapped, besides, accumulated, regatta,
#
#  Average loss after epoch  68  : 3.001635421545078
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, india,
# Similar to <eos>: single-family, just, baseball, philippines, stopped,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, mirror, century,
# Similar to $: wildly, john, material, defeat, hero,
# Similar to on: removed, attracts, join, beneficiaries, harmony,
# Similar to i: throughout, scrapped, besides, accumulated, regatta,
#
#  Average loss after epoch  69  : 3.006834546724955
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, just, relations, stopped, baseball,
# Similar to were: posted, priced, october, come, advertised,
# Similar to of: inched, drop, suppliers, below, estimated,
# Similar to $: wildly, john, material, defeat, hero,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, accumulated, scrapped, besides, regatta,
#
#  Average loss after epoch  70  : 2.99773878737902
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, just, stopped, relations, philippines,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, estimated, mirror,
# Similar to $: wildly, john, material, defeat, hero,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  71  : 2.9770562595281844
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, baseball, relations, just, stopped,
# Similar to were: posted, october, priced, come, advertised,
# Similar to of: inched, suppliers, drop, preferences, below,
# Similar to $: wildly, john, material, defeat, hero,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  72  : 2.9927729597458472
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, duty-free, washington-based,
# Similar to <eos>: single-family, baseball, stopped, just, relations,
# Similar to were: posted, october, priced, advertised, lent,
# Similar to of: inched, suppliers, drop, estimated, century,
# Similar to $: wildly, john, material, hero, defeat,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  73  : 2.9754154128141894
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, relations, stopped, baseball, philippines,
# Similar to were: posted, october, advertised, lent, priced,
# Similar to of: inched, suppliers, drop, below, estimated,
# Similar to $: john, wildly, material, doubled, defeat,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, distribution,
#
#  Average loss after epoch  74  : 2.983848906098268
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, washington-based, duty-free,
# Similar to <eos>: single-family, relations, baseball, just, working,
# Similar to were: posted, october, advertised, lent, priced,
# Similar to of: inched, suppliers, drop, mirror, estimated,
# Similar to $: wildly, john, material, defeat, doubled,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  75  : 2.989077859964126
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, duty-free, washington-based,
# Similar to <eos>: single-family, relations, baseball, stopped, philippines,
# Similar to were: posted, october, lent, advertised, priced,
# Similar to of: inched, suppliers, drop, mirror, estimated,
# Similar to $: wildly, john, material, doubled, hero,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  76  : 2.967286611978824
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, washington-based,
# Similar to <eos>: single-family, relations, stopped, baseball, just,
# Similar to were: posted, october, advertised, lent, come,
# Similar to of: inched, suppliers, drop, mirror, century,
# Similar to $: material, john, wildly, doubled, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  77  : 2.9612555694885745
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, details,
# Similar to <eos>: relations, single-family, stopped, baseball, philippines,
# Similar to were: posted, october, advertised, lent, come,
# Similar to of: inched, suppliers, drop, estimated, preferences,
# Similar to $: john, wildly, material, doubled, money-fund,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  78  : 2.967935022253257
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: single-family, relations, stopped, baseball, just,
# Similar to were: posted, october, advertised, lent, come,
# Similar to of: inched, suppliers, drop, estimated, century,
# Similar to $: john, wildly, doubled, material, money-fund,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  79  : 2.9732423944351
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: just, relations, stopped, philippines, baseball,
# Similar to were: posted, october, advertised, lent, man,
# Similar to of: inched, suppliers, drop, below, estimated,
# Similar to $: john, wildly, doubled, material, defeat,
# Similar to on: removed, attracts, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  80  : 2.9631245132440176
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: relations, single-family, stopped, baseball, philippines,
# Similar to were: posted, october, advertised, lent, priced,
# Similar to of: inched, drop, suppliers, estimated, mirror,
# Similar to $: john, wildly, doubled, material, money-fund,
# Similar to on: attracts, removed, join, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  81  : 2.9548130318140373
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, least, duty-free,
# Similar to <eos>: single-family, baseball, relations, stopped, just,
# Similar to were: posted, october, advertised, lent, come,
# Similar to of: inched, suppliers, drop, estimated, mirror,
# Similar to $: john, wildly, doubled, material, defeat,
# Similar to on: attracts, removed, join, beneficiaries, harmony,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  82  : 2.965404421855242
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: philippines, baseball, single-family, stopped, relations,
# Similar to were: posted, advertised, october, lent, come,
# Similar to of: inched, suppliers, drop, mirror, estimated,
# Similar to $: john, doubled, wildly, material, visit,
# Similar to on: join, removed, attracts, beneficiaries, harmony,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  83  : 2.9506594080191393
# Similar to two: pierre, shore, computing, guaranteed, washington-based,
# Similar to share: favored, pending, chefs, least, duty-free,
# Similar to <eos>: single-family, baseball, relations, stopped, philippines,
# Similar to were: posted, advertised, october, lent, come,
# Similar to of: inched, suppliers, drop, mirror, estimated,
# Similar to $: john, material, doubled, wildly, defeat,
# Similar to on: join, removed, attracts, beneficiaries, harmony,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  84  : 2.9486374201682897
# Similar to two: pierre, shore, computing, guaranteed, signs,
# Similar to share: favored, pending, chefs, least, duty-free,
# Similar to <eos>: relations, single-family, stopped, go, philippines,
# Similar to were: posted, advertised, lent, october, come,
# Similar to of: inched, suppliers, drop, mirror, century,
# Similar to $: wildly, john, doubled, material, defeat,
# Similar to on: removed, join, attracts, beneficiaries, harmony,
# Similar to i: throughout, scrapped, besides, accumulated, regatta,
#
#  Average loss after epoch  85  : 2.9634037820192485
# Similar to two: pierre, shore, computing, guaranteed, elected,
# Similar to share: favored, duty-free, pending, chefs, least,
# Similar to <eos>: single-family, relations, baseball, just, stopped,
# Similar to were: posted, october, lent, advertised, come,
# Similar to of: inched, suppliers, drop, mirror, estimated,
# Similar to $: john, wildly, doubled, visit, material,
# Similar to on: removed, join, attracts, beneficiaries, harmony,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  86  : 2.9492464615748477
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, duty-free, least, chefs,
# Similar to <eos>: single-family, relations, baseball, stopped, philippines,
# Similar to were: posted, lent, advertised, october, priced,
# Similar to of: suppliers, inched, drop, century, mirror,
# Similar to $: john, wildly, defeat, doubled, material,
# Similar to on: removed, attracts, join, beneficiaries, harmony,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  87  : 2.948074051967034
# Similar to two: pierre, shore, computing, guaranteed, elected,
# Similar to share: favored, pending, duty-free, chefs, least,
# Similar to <eos>: single-family, relations, baseball, stopped, philippines,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, suppliers, drop, estimated, mirror,
# Similar to $: john, wildly, visit, doubled, material,
# Similar to on: removed, attracts, join, beneficiaries, harmony,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  88  : 2.9373049415074863
# Similar to two: pierre, shore, computing, guaranteed, elected,
# Similar to share: favored, duty-free, pending, chefs, least,
# Similar to <eos>: relations, single-family, stopped, baseball, philippines,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, suppliers, drop, mirror, century,
# Similar to $: john, wildly, material, defeat, visit,
# Similar to on: removed, join, attracts, beneficiaries, harmony,
# Similar to i: throughout, scrapped, besides, accumulated, regatta,
#
#  Average loss after epoch  89  : 2.9500657499600678
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, duty-free, least, chefs,
# Similar to <eos>: relations, single-family, baseball, philippines, stopped,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, drop, suppliers, preferences, mirror,
# Similar to $: john, wildly, visit, posted, material,
# Similar to on: removed, join, attracts, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, besides, regatta,
#
#  Average loss after epoch  90  : 2.94752453878904
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, duty-free, chefs, least,
# Similar to <eos>: single-family, relations, baseball, stopped, philippines,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, suppliers, drop, mirror, century,
# Similar to $: john, wildly, visit, posted, material,
# Similar to on: removed, join, attracts, beneficiaries, requested,
# Similar to i: throughout, scrapped, accumulated, regatta, besides,
#
#  Average loss after epoch  91  : 2.9380117807632837
# Similar to two: pierre, shore, computing, guaranteed, elected,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: single-family, relations, stopped, baseball, just,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, drop, suppliers, pharmaceuticals, estimated,
# Similar to $: john, wildly, visit, material, defeat,
# Similar to on: removed, join, attracts, beneficiaries, stadium,
# Similar to i: throughout, scrapped, accumulated, regatta, besides,
#
#  Average loss after epoch  92  : 2.9374471589540825
# Similar to two: pierre, shore, computing, guaranteed, elected,
# Similar to share: favored, pending, chefs, least, duty-free,
# Similar to <eos>: relations, single-family, just, baseball, stopped,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, drop, pharmaceuticals, suppliers, century,
# Similar to $: john, visit, wildly, defeat, material,
# Similar to on: removed, join, attracts, beneficiaries, stadium,
# Similar to i: throughout, scrapped, regatta, accumulated, besides,
#
#  Average loss after epoch  93  : 2.934586131419891
# Similar to two: pierre, shore, computing, guaranteed, elected,
# Similar to share: favored, pending, chefs, least, duty-free,
# Similar to <eos>: relations, stopped, single-family, baseball, philippines,
# Similar to were: posted, lent, advertised, october, come,
# Similar to of: inched, drop, suppliers, century, pharmaceuticals,
# Similar to $: john, visit, defeat, wildly, doubled,
# Similar to on: join, removed, attracts, beneficiaries, requested,
# Similar to i: throughout, scrapped, regatta, accumulated, besides,
#
#  Average loss after epoch  94  : 2.947065737002935
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: relations, N, baseball, single-family, stopped,
# Similar to were: posted, lent, advertised, october, come,
# Similar to of: inched, drop, suppliers, pharmaceuticals, mirror,
# Similar to $: john, wildly, defeat, doubled, visit,
# Similar to on: removed, join, attracts, beneficiaries, stadium,
# Similar to i: scrapped, throughout, regatta, accumulated, besides,
#
#  Average loss after epoch  95  : 2.9282805728606687
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: relations, baseball, philippines, single-family, stopped,
# Similar to were: posted, lent, october, advertised, come,
# Similar to of: inched, drop, suppliers, pharmaceuticals, mirror,
# Similar to $: john, wildly, visit, posted, material,
# Similar to on: join, removed, attracts, beneficiaries, stadium,
# Similar to i: scrapped, throughout, regatta, accumulated, besides,
#
#  Average loss after epoch  96  : 2.9171511626396422
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: relations, baseball, philippines, just, single-family,
# Similar to were: posted, lent, advertised, october, come,
# Similar to of: inched, suppliers, drop, mirror, preferences,
# Similar to $: john, visit, defeat, wildly, posted,
# Similar to on: join, removed, attracts, beneficiaries, stadium,
# Similar to i: scrapped, throughout, regatta, accumulated, besides,
#
#  Average loss after epoch  97  : 2.91895131728588
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: relations, single-family, just, baseball, N,
# Similar to were: posted, advertised, lent, october, n.h.,
# Similar to of: inched, drop, suppliers, mirror, preferences,
# Similar to $: visit, wildly, john, defeat, posted,
# Similar to on: join, removed, attracts, beneficiaries, stadium,
# Similar to i: scrapped, throughout, regatta, besides, accumulated,
#
#  Average loss after epoch  98  : 2.9138197914147987
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, duty-free, least,
# Similar to <eos>: relations, single-family, working, stopped, baseball,
# Similar to were: posted, advertised, lent, october, come,
# Similar to of: inched, drop, suppliers, century, below,
# Similar to $: visit, wildly, john, doubled, posted,
# Similar to on: join, removed, attracts, beneficiaries, stadium,
# Similar to i: scrapped, throughout, regatta, besides, accumulated,
#
#  Average loss after epoch  99  : 2.927240026684908
# Similar to two: pierre, shore, computing, guaranteed, downtown,
# Similar to share: favored, pending, chefs, least, duty-free,
# Similar to <eos>: single-family, relations, stopped, baseball, philippines,
# Similar to were: posted, advertised, lent, october, n.h.,
# Similar to of: inched, drop, suppliers, mirror, century,
# Similar to $: john, visit, wildly, posted, doubled,
# Similar to on: join, attracts, removed, beneficiaries, stadium,
# Similar to i: scrapped, throughout, regatta, besides, accumulated,

# %%
def plot_with_labels(low_dim_embs, labels):
    assert low_dim_embs.shape[0] >= len(
        labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')
    plt.show()


from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

tsne = TSNE(perplexity=30, n_components=2,
            init='pca', n_iter=5000, method='exact')
n_embeddings = 500
low_dim_embeddings = tsne.fit_transform(final_embeddings[:n_embeddings, :])
labels = [ptb.id2word[i] for i in range(n_embeddings)]

plot_with_labels(low_dim_embeddings, labels)
